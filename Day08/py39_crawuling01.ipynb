# %% [markdown]
# #### 멜론 노래순위 정보 크롤링
#
# 크롬드라이버

# %%
from selenium import webdriver

driver = webdriver.Chrome()

# %%
# 멜론 차트로 진입
url = 'https://www.melon.com/chart/index.htm'
driver.get(url)

# %%
# beautifulSoap로 HTML 다운로드
from bs4 import BeautifulSoup

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser') # html.parser, xml, lxml, html5lib
soup
# Out:
# <html class="chrome chrome114" lang="ko"><head>
# <!-- bgsweb-www903 -->
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="노래추천, 음악추천, 플레이리스트, essential, 에센셜, 스트리밍, 스밍, 뮤직PD, 노래듣기, 음악다운로드, 페이코" name="keywords"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script async="" crossorigin="anonymous" src="https://connect.facebook.net/ko_KR/sdk.js?hash=af8338a21f2f7a1c14d2041e06d59b56"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script src="https://atm.acecounter.com/ac.js?tid=103005CR-30-A&amp;hsn=music.bugs.co.kr&amp;hrf=&amp;dvp=0&amp;tgp=&amp;tn1=&amp;tn2=0&amp;tn3=0&amp;tw1=&amp;tw2=&amp;tw3=&amp;tw4=&amp;tw5=&amp;tw6=&amp;tw7=&amp;rnd=1687845765921&amp;py=0"></script><script id="facebook-jssdk" src="//connect.facebook.com/ko_KR/sdk.js"></script><script type="text/javascript">
# 	if(!(location.href.indexOf("music.bugs.co.kr/newPlayer") >= 0 || location.href.indexOf("music.bugs.co.kr/newRadio") >= 0 || location.href.indexOf("localhost") >= 0
#         || location.href.indexOf("help.bugs.co.kr") >= 0))
# 		document.domain = 'bugs.co.kr';
#
# 	var g_urlBase = "https://www.bugs.co.kr";
# 	var g_urlWww = "https://www.bugs.co.kr";
# 	var g_urlSecure = "https://secure.bugs.co.kr";
# 	var g_urlMusic = "https://music.bugs.co.kr";
# 	var g_urlMusicSecure = "https://music.bugs.co.kr";
# 	var g_urlMember = "https://secure.bugs.co.kr/member";
# 	var g_urlFile = "https://file.bugsm.co.kr/wbugs";
# 	var g_urlFile_n ="https://file.bugsm.co.kr/nbugs";
# 	//var g_urlSwf = "https://music.bugs.co.kr/swf";
# 	var g_urlSwf = "https://music.bugs.co.kr/swf";
# 	var g_urlJs = "/js";
# 	var g_urlMe = "https://music.bugs.co.kr/user";
# 	var g_urlThumbnail = "http://nboardr.bugs.co.kr/thumbnail";
# 	var g_urlOpenalbum = "https://music.bugs.co.kr/openalbum";
# 	var g_urlClipimg = "//image.bugsm.co.kr";
# 	//var g_urlLikes = "https://music.bugs.co.kr/like";
# 	//var g_urlPlaylists = "https://music.bugs.co.kr/playlist";
# 	var g_urlLikes = "https://music.bugs.co.kr/like";
# 	var g_urlPlaylists = "https://music.bugs.co.kr/playlist"
# 	var g_urlListen = "https://music.bugs.co.kr/listen";
# 	var g_urlMyinfo = "https://music.bugs.co.kr/myinfo";
# 	var g_urlSecureMyinfo = "https://secure.bugs.co.kr/myinfo";
# 	var g_urlSearch = "https://music.bugs.co.kr/search";
# 	var g_urlChart = "https://music.bugs.co.kr/chart";
# 	var g_urlPay = "https://music.bugs.co.kr/pay";
# 	var g_urlBilling = "https://pay.bugs.co.kr";
# 	var g_urlPartner = "https://www.bugs.co.kr/Partner";
# 	var g_urlSecurePay = "https://secure.bugs.co.kr/pay";
# 	var g_urlOtu = "https://notu.bugs.co.kr";
# 	var g_urlBoard = "http://board.bugs.co.kr/notice";
# 	var g_urlEvent = "https://music.bugs.co.kr/event";
# 	var g_storageServerRead = "http://nboardr.bugs.co.kr";
# 	var g_storageServerWrite = "https://nboardw.bugs.co.kr";
#     var g_storageServerFileUploadTmp = g_storageServerWrite+"/adminimg/storage/upload";
# 	var g_urlPanel = "https://music.bugs.co.kr/panel";
# 	var g_urlAjax = "https://music.bugs.co.kr";
# 	var g_urlAppsvr = "https://music.bugs.co.kr";
# 	var g_urlMusicPd = "https://music.bugs.co.kr/musicpd";
# 	var g_urlGenre = "https://music.bugs.co.kr/genre";
# 	var g_urlMLounge = "https://mlounge.bugs.co.kr";
# 	var g_urlNinanoclub = "http://ninanoclub.bugs.co.kr";
# 	var g_urlM = "https://m.bugs.co.kr";
# 	var g_urlDl = "https://dl.bugs.co.kr";
# 	var g_urlBGT = "https://bgt.bugs.co.kr";
#
# 	var g_env = "svc";
#
# 	var g_isLogged = false;
# 	var g_msrl = false;
# </script>
# <!-- cache.filePacking : true -->
# <!-- bugs file packing [ open_lib_js ] cached data / start -->
# <script src="//music.bugs.co.kr/filepacking/open_lib_js?env=svc&amp;_t_s_=20230627-1502" type="text/javascript"></script>
# <!-- bugs file packing [ open_lib_js ] cached data / end -->
# <!-- bugs file packing [ bugs_desktopLib_js ] cached data / start -->
# <script src="//music.bugs.co.kr/filepacking/bugs_desktopLib_js?env=svc&amp;_t_s_=20230627-1502" type="text/javascript"></script>
# <!-- bugs file packing [ bugs_desktopLib_js ] cached data / end -->
# <!-- bugs file packing [ bugs_newLib_js ] cached data / start -->
# <script src="//music.bugs.co.kr/filepacking/bugs_newLib_js?env=svc&amp;_t_s_=20230627-1502" type="text/javascript"></script>
# <!-- bugs file packing [ bugs_newLib_js ] cached data / end -->
# <!-- clova issue로 분기 -->
# <script src="/js/swfobject/swfobject.js" type="text/javascript"></script>
# <!-- java enum to js -->
# <script src="https://music.bugs.co.kr/js/enumtojs" type="text/javascript"></script>
# <script src="/js/utils/personMedia.js?version=20220420" type="text/javascript"></script>
# <script src="/js/me/playlist.js?version=20151102" type="text/javascript"></script>
# <script src="/js/log/makePCookie.js" type="text/javascript"></script>
# <script src="/js/player/min/mvHtml5Player.min.js?version=20230627:1502" type="text/javascript"></script>
# <!-- <script type="text/javascript" src="/js/utils/fileUploader.js"></script> -->
# <script src="/js/lib/kakao.min.js" type="text/javascript"></script> <!-- <script type="text/javascript" src="/js/lib/kakao.story.min.js"></script> -->
# <!--[if gt IE 7]>
# 	<script type="text/javascript" src="/js/jquery/jquery.ba-hashchange.min.js"></script>
# <![endif]-->
# <!--[if lt IE 9]>
# 	<script type="text/javascript" src="/js/html5/html5shiv.min.js"></script>
# 	<script type="text/javascript" src="/js/json2.js"></script>
# <![endif]-->
# <!-- bugs file packing [ bugs_commonStyle_css ] cached data / start -->
# <link href="//music.bugs.co.kr/filepacking/bugs_commonStyle_css?env=svc&amp;_t_s_=20230627-1502" rel="stylesheet" type="text/css"/>
# <!-- bugs file packing [ bugs_commonStyle_css ] cached data / end -->
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="https://music.bugs.co.kr/chart/track/realtime/total" name="twitter:url"/>
# <meta content="벅스!에서 다양한 음악컨텐츠를 볼 수 있습니다." name="twitter:description"/>
# <meta content="https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png" name="twitter:image:src"/>
# <meta content="bugs3://app/whatshot/chart" name="twitter:app:url:iphone"/>
# <meta content="bugs3://app/whatshot/chart" name="twitter:app:url:ipad"/>
# <meta content="bugs3://app/whatshot/chart" name="twitter:app:url:googleplay"/>
# <meta content="나를 위한 플리, 벅스! 마음을 담은 노래추천 플레이리스트, 그리고 일상을 감성으로 가득 채워줄 essential player까지" name="description"/>
# <!-- open graph -->
# <meta content="122936701116206" property="fb:app_id"/>
# <meta content="나를 위한 플리, 벅스" property="og:title"/>
# <meta content="https://music.bugs.co.kr/chart" property="og:url"/>
# <meta content="https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png" property="og:image"/>
# <meta content="벅스!" property="og:site_name"/>
# <meta content="나를 위한 플리, 벅스! 마음을 담은 노래추천 플레이리스트, 그리고 일상을 감성으로 가득 채워줄 essential player까지" property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="ko_KR" property="og:locale"/>
# <!-- twitter card -->
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="https://music.bugs.co.kr/chart" name="twitter:url"/>
# <meta content="@Bugs_play" name="twitter:site"/>
# <meta content="나를 위한 플리, 벅스" name="twitter:title"/>
# <meta content="나를 위한 플리, 벅스! 마음을 담은 노래추천 플레이리스트, 그리고 일상을 감성으로 가득 채워줄 essential player까지" name="twitter:description"/>
# <meta content="https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png" name="twitter:image"/>
# <meta content="https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png" name="twitter:image:src"/>
# <meta content="벅스" name="twitter:app:name:iphone"/>
# <meta content="벅스" name="twitter:app:name:ipad"/>
# <meta content="벅스" name="twitter:app:name:googleplay"/>
# <meta content="https://music.bugs.co.kr/chart" name="twitter:app:url:iphone"/>
# <meta content="https://music.bugs.co.kr/chart" name="twitter:app:url:ipad"/>
# <meta content="https://music.bugs.co.kr/chart" name="twitter:app:url:googleplay"/>
# <meta content="348555322" name="twitter:app:id:iphone"/>
# <meta content="420598915" name="twitter:app:id:ipad"/>
# <meta content="com.neowiz.android.bugs" name="twitter:app:id:googleplay"/>
# <link href="https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png" rel="image_src"/>
# <meta content="https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png" itemprop="image"/>
# <!-- bugs.sns 용 공유 파라미터 -->
# <script>
# 			var bugsSnsParam = {
# 		 			url : "https://music.bugs.co.kr/chart",
# 		 			text : "나를 위한 플리, 벅스",
# 		 			img : "https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png",
# 		 			hashTag : "#벅스",
# 		 			corner : "벅스"
# 		 		}
# 		</script>
# <script>
#       		 var bugsSnsParam2 = {
#                         url : "https://music.bugs.co.kr/chart",
#                         text : "#2018_우리가_사랑한_음악",
#                         img : "https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png",
#                         hashTag : "#벅스",
#                         corner : "벅스"
#                     }
# 		</script>
# <meta content="ko_KR" property="og:locale"/>
# <title>벅스차트 &gt; 곡 차트 &gt; 실시간 &gt; 전체 장르 - 벅스</title>
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <!-- 네이버 검색용 메타 -->
# <meta content="0582453e44d4365f5e597d1580911be7a3173ef7" name="naver-site-verification"/>
# <!-- bugs file packing [ bugs_wbugsAll_css ] cached data / start -->
# <link href="//music.bugs.co.kr/filepacking/bugs_wbugsAll_css?env=svc&amp;_t_s_=20230627-1502" rel="stylesheet" type="text/css"/>
# <!-- bugs file packing [ bugs_wbugsAll_css ] cached data / end -->
# <link href="https://file.bugsm.co.kr/wbugs/common/faviconBugs.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://file.bugsm.co.kr/wbugs/common/faviconBugs.ico" rel="icon" type="image/x-icon"/>
# <script src="/js/log/ace_counter.js"></script>
# <script>
# 	$(document).ready(function(){
# 		$("[dotdotdot=Y]").dotdotdot({
# 			watch : "window"
# 		});
# 	});
# 	</script>
# <meta content="" name="last-process-time"/>
# <script src="/js/enc/gibberish-aes.js" type="text/javascript"></script><style data-fbcssmodules="css:fb.css.base css:fb.css.dialog css:fb.css.iframewidget css:fb.css.customer_chat_plugin_iframe" type="text/css">.fb_hidden{position:absolute;top:-10000px;z-index:10001}.fb_reposition{overflow:hidden;position:relative}.fb_invisible{display:none}.fb_reset{background:none;border:0;border-spacing:0;color:#000;cursor:auto;direction:ltr;font-family:'lucida grande', tahoma, verdana, arial, sans-serif;font-size:11px;font-style:normal;font-variant:normal;font-weight:normal;letter-spacing:normal;line-height:1;margin:0;overflow:visible;padding:0;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;visibility:visible;white-space:normal;word-spacing:normal}.fb_reset>div{overflow:hidden}@keyframes fb_transform{from{opacity:0;transform:scale(.95)}to{opacity:1;transform:scale(1)}}.fb_animate{animation:fb_transform .3s forwards}
# .fb_dialog{background:rgba(82, 82, 82, .7);position:absolute;top:-10000px;z-index:10001}.fb_dialog_advanced{border-radius:8px;padding:10px}.fb_dialog_content{background:#fff;color:#373737}.fb_dialog_close_icon{background:url(https://connect.facebook.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 0 transparent;cursor:pointer;display:block;height:15px;position:absolute;right:18px;top:17px;width:15px}.fb_dialog_mobile .fb_dialog_close_icon{left:5px;right:auto;top:5px}.fb_dialog_padding{background-color:transparent;position:absolute;width:1px;z-index:-1}.fb_dialog_close_icon:hover{background:url(https://connect.facebook.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -15px transparent}.fb_dialog_close_icon:active{background:url(https://connect.facebook.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -30px transparent}.fb_dialog_iframe{line-height:0}.fb_dialog_content .dialog_title{background:#6d84b4;border:1px solid #365899;color:#fff;font-size:14px;font-weight:bold;margin:0}.fb_dialog_content .dialog_title>span{background:url(https://connect.facebook.net/rsrc.php/v3/yd/r/Cou7n-nqK52.gif) no-repeat 5px 50%;float:left;padding:5px 0 7px 26px}body.fb_hidden{height:100%;left:0;margin:0;overflow:visible;position:absolute;top:-10000px;transform:none;width:100%}.fb_dialog.fb_dialog_mobile.loading{background:url(https://connect.facebook.net/rsrc.php/v3/ya/r/3rhSv5V8j3o.gif) white no-repeat 50% 50%;min-height:100%;min-width:100%;overflow:hidden;position:absolute;top:0;z-index:10001}.fb_dialog.fb_dialog_mobile.loading.centered{background:none;height:auto;min-height:initial;min-width:initial;width:auto}.fb_dialog.fb_dialog_mobile.loading.centered #fb_dialog_loader_spinner{width:100%}.fb_dialog.fb_dialog_mobile.loading.centered .fb_dialog_content{background:none}.loading.centered #fb_dialog_loader_close{clear:both;color:#fff;display:block;font-size:18px;padding-top:20px}#fb-root #fb_dialog_ipad_overlay{background:rgba(0, 0, 0, .4);bottom:0;left:0;min-height:100%;position:absolute;right:0;top:0;width:100%;z-index:10000}#fb-root #fb_dialog_ipad_overlay.hidden{display:none}.fb_dialog.fb_dialog_mobile.loading iframe{visibility:hidden}.fb_dialog_mobile .fb_dialog_iframe{position:sticky;top:0}.fb_dialog_content .dialog_header{background:linear-gradient(from(#738aba), to(#2c4987));border-bottom:1px solid;border-color:#043b87;box-shadow:white 0 1px 1px -1px inset;color:#fff;font:bold 14px Helvetica, sans-serif;text-overflow:ellipsis;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0;vertical-align:middle;white-space:nowrap}.fb_dialog_content .dialog_header table{height:43px;width:100%}.fb_dialog_content .dialog_header td.header_left{font-size:12px;padding-left:5px;vertical-align:middle;width:60px}.fb_dialog_content .dialog_header td.header_right{font-size:12px;padding-right:5px;vertical-align:middle;width:60px}.fb_dialog_content .touchable_button{background:linear-gradient(from(#4267B2), to(#2a4887));background-clip:padding-box;border:1px solid #29487d;border-radius:3px;display:inline-block;line-height:18px;margin-top:3px;max-width:85px;padding:4px 12px;position:relative}.fb_dialog_content .dialog_header .touchable_button input{background:none;border:none;color:#fff;font:bold 12px Helvetica, sans-serif;margin:2px -12px;padding:2px 6px 3px 6px;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0}.fb_dialog_content .dialog_header .header_center{color:#fff;font-size:16px;font-weight:bold;line-height:18px;text-align:center;vertical-align:middle}.fb_dialog_content .dialog_content{background:url(https://connect.facebook.net/rsrc.php/v3/y9/r/jKEcVPZFk-2.gif) no-repeat 50% 50%;border:1px solid #4a4a4a;border-bottom:0;border-top:0;height:150px}.fb_dialog_content .dialog_footer{background:#f5f6f7;border:1px solid #4a4a4a;border-top-color:#ccc;height:40px}#fb_dialog_loader_close{float:left}.fb_dialog.fb_dialog_mobile .fb_dialog_close_icon{visibility:hidden}#fb_dialog_loader_spinner{animation:rotateSpinner 1.2s linear infinite;background-color:tr ...
# .fb_iframe_widget{display:inline-block;position:relative}.fb_iframe_widget span{display:inline-block;position:relative;text-align:justify}.fb_iframe_widget iframe{position:absolute}.fb_iframe_widget_fluid_desktop,.fb_iframe_widget_fluid_desktop span,.fb_iframe_widget_fluid_desktop iframe{max-width:100%}.fb_iframe_widget_fluid_desktop iframe{min-width:220px;position:relative}.fb_iframe_widget_lift{z-index:1}.fb_iframe_widget_fluid{display:inline}.fb_iframe_widget_fluid span{width:100%}
# .fb_mpn_mobile_landing_page_slide_out{animation-duration:200ms;animation-name:fb_mpn_landing_page_slide_out;transition-timing-function:ease-in}.fb_mpn_mobile_landing_page_slide_out_from_left{animation-duration:200ms;animation-name:fb_mpn_landing_page_slide_out_from_left;transition-timing-function:ease-in}.fb_mpn_mobile_landing_page_slide_up{animation-duration:500ms;animation-name:fb_mpn_landing_page_slide_up;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_in{animation-duration:300ms;animation-name:fb_mpn_bounce_in;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_out{animation-duration:300ms;animation-name:fb_mpn_bounce_out;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_out_v2{animation-duration:300ms;animation-name:fb_mpn_fade_out;transition-timing-function:ease-in}.fb_customer_chat_bounce_in_v2{animation-duration:300ms;animation-name:fb_bounce_in_v2;transition-timing-function:ease-in}.fb_customer_chat_bounce_in_from_left{animation-duration:300ms;animation-name:fb_bounce_in_from_left;transition-timing-function:ease-in}.fb_customer_chat_bounce_out_v2{animation-duration:300ms;animation-name:fb_bounce_out_v2;transition-timing-function:ease-in}.fb_customer_chat_bounce_out_from_left{animation-duration:300ms;animation-name:fb_bounce_out_from_left;transition-timing-function:ease-in}.fb_invisible_flow{display:inherit;height:0;overflow-x:hidden;width:0}@keyframes fb_mpn_landing_page_slide_out{0%{margin:0 12px;width:100% - 24px}60%{border-radius:18px}100%{border-radius:50%;margin:0 24px;width:60px}}@keyframes fb_mpn_landing_page_slide_out_from_left{0%{left:12px;width:100% - 24px}60%{border-radius:18px}100%{border-radius:50%;left:12px;width:60px}}@keyframes fb_mpn_landing_page_slide_up{0%{bottom:0;opacity:0}100%{bottom:24px;opacity:1}}@keyframes fb_mpn_bounce_in{0%{opacity:.5;top:100%}100%{opacity:1;top:0}}@keyframes fb_mpn_fade_out{0%{bottom:30px;opacity:1}100%{bottom:0;opacity:0}}@keyframes fb_mpn_bounce_out{0%{opacity:1;top:0}100%{opacity:.5;top:100%}}@keyframes fb_bounce_in_v2{0%{opacity:0;transform:scale(0, 0);transform-origin:bottom right}50%{transform:scale(1.03, 1.03);transform-origin:bottom right}100%{opacity:1;transform:scale(1, 1);transform-origin:bottom right}}@keyframes fb_bounce_in_from_left{0%{opacity:0;transform:scale(0, 0);transform-origin:bottom left}50%{transform:scale(1.03, 1.03);transform-origin:bottom left}100%{opacity:1;transform:scale(1, 1);transform-origin:bottom left}}@keyframes fb_bounce_out_v2{0%{opacity:1;transform:scale(1, 1);transform-origin:bottom right}100%{opacity:0;transform:scale(0, 0);transform-origin:bottom right}}@keyframes fb_bounce_out_from_left{0%{opacity:1;transform:scale(1, 1);transform-origin:bottom left}100%{opacity:0;transform:scale(0, 0);transform-origin:bottom left}}@keyframes slideInFromBottom{0%{opacity:.1;transform:translateY(100%)}100%{opacity:1;transform:translateY(0)}}@keyframes slideInFromBottomDelay{0%{opacity:0;transform:translateY(100%)}97%{opacity:0;transform:translateY(100%)}100%{opacity:1;transform:translateY(0)}}</style></head><body><span itemscope="" itemtype="http://schema.org/Organization">
# <link href="https://music.bugs.co.kr" itemprop="url"/>
# <a href="https://www.facebook.com/bugsplay" itemprop="sameAs"></a>
# <a href="http://blog.bugs.co.kr" itemprop="sameAs"></a>
# <a href="https://twitter.com/bugs_play" itemprop="sameAs"></a>
# <a href="https://itunes.apple.com/kr/app/bugs/id348555322?mt=8" itemprop="sameAs"></a>
# <a href="https://play.google.com/store/apps/details?id=com.neowiz.android.bugs" itemprop="sameAs"></a>
# </span>
# <script type="text/javascript">
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#       m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#
#   try {
#     ga('create', 'UA-97174709-1', 'auto', 'billingTracker');
#   } catch (e) {
#     console.log('GoogleAnalytics Create Error');
#   }
#
#     var sendGoogleAnalyticsEventForBilling = function (category, action, label) {
#       try {
#         ga('billingTracker.send', 'event', category, action, label);
#       } catch (e) {
#         console.log('GoogleAnalytics Send Event Error');
#       }
#     }
#
# </script>
# <div id="skipNav">
# <a href="#container" onclick="$('#container').attr('tabIndex','-1');$('#container').focus();$('body,html').scrollTop(0);return false;"><span>본문 바로가기</span></a>
# <a href="#gnb" onclick="bugs.navigator.setLeftMenuShow(true,true);$('#gnb').attr('tabIndex','-1');$('#gnb').focus();return false;"><span>메뉴 바로가기</span></a>
# <a href="#loginHeader" onclick="$('#loginHeader a:first-of-type').attr('tabIndex','-1');$('#loginHeader a:first-of-type').focus();return false;"><span>로그인 바로가기</span></a>
# <a href="#footer" onclick="$('#footer').attr('tabIndex','-1');$('#footer').focus();return false;"><span>하단 정보 바로가기</span></a>
# </div>
# <div id="wrap">
# <script>
# 	$(document).ready(function(){
# 					if('' == ""){
# 				bugs.searchBoxAd.init();
# 				bugs.searchBoxAd.checkInput();
# 				bugs.searchBoxAd.inputBlur();
# 				bugs.searchBoxAd.deleteText();
# 			}
#
# 		popWebPlayerNotification();
#
# 		bugs.suggest.close();
# 		var headerCommonBanner = '[{\"image_bg_color\":\"\",\"clickCount\":0,\"artist\":null,\"sub_category\":\"main\",\"crt_dt\":\"\",\"db_sts\":\"\",\"link\":\"https://music.bugs.co.kr/radio/musiccast/episode/31166\",\"view_target\":\"ALL\",\"title\":\"러비의 일촌신청 154화\",\"str_content_id\":\"0\",\"content_type\":\"NONE\",\"crt_id\":\"\",\"track\":null,\"view_env\":\"SVC\",\"content_id2\":\"\",\"pay_yn\":\"\",\"banner_id\":108719,\"content_id\":0,\"album\":null,\"upd_dt\":\"\",\"mv\":null,\"weight\":20,\"image_path2\":\"\",\"artist_id\":\"0\",\"mobile_target\":\"\",\"target\":\"_self\",\"upd_id\":\"\",\"wiselog_code\":\"\",\"file_ext\":\"\",\"css_class_nm\":\"\",\"image_path\":\"//image.bugsm.co.kr/banner/images/original/719/108/0/108719.jpg\",\"view_start_date\":{\"date\":26,\"hours\":17,\"seconds\":0,\"month\":5,\"timezoneOffset\":-540,\"year\":123,\"minutes\":0,\"time\":1687766400000,\"day\":1},\"expire_day\":0,\"regdate\":{\"date\":26,\"hours\":14,\"seconds\":40,\"month\":5,\"timezoneOffset\":-540,\"year\":123,\"minutes\":26,\"time\":1687757200000,\"day\":1},\"totalWeight\":0,\"app_nm\":\"\",\"album_id\":\"0\",\"lastupdate\":{\"date\":26,\"hours\":14,\"seconds\":40,\"month\":5,\"timezoneOffset\":-540,\"year\":123,\"minutes\":26,\"time\":1687757200000,\"day\":1},\"view_end_date\":{\"date\":3,\"hours\":17,\"seconds\":0,\"month\":6,\"timezoneOffset\":-540,\"year\":123,\"minutes\":0,\"time\":1688371200000,\"day\":1},\"category\":\"WBUGS_HEADER_COMMON_BANNER\",\"status\":\"OK\"},{\"image_bg_color\":\"\",\"clickCount\":0,\"artist\":null,\"sub_category\":\"main\",\"crt_dt\":\"\",\"db_sts\":\"\",\"link\":\"https://music.bugs.co.kr/radio/musiccast/episode/31147\",\"view_target\":\"ALL\",\"title\":\"소이의 이상한 하루 164화\",\"str_content_id\":\"0\",\"content_type\":\"NONE\",\"crt_id\":\"\",\"track\":null,\"view_env\":\"SVC\",\"content_id2\":\"\",\"pay_yn\":\"\",\"banner_id\":108633,\"content_id\":0,\"album\":null,\"upd_dt\":\"\",\"mv\":null,\"weight\":20,\"image_path2\":\"\",\"artist_id\":\"0\",\"mobile_target\":\"\",\"target\":\"_self\",\"upd_id\":\"\",\"wiselog_code\":\"\",\"file_ext\":\"\",\"css_class_nm\":\"\",\"image_path\":\"//image.bugsm.co.kr/banner/images/original/633/108/0/108633.jpg\",\"view_start_date\":{\"date\":23,\"hours\":17,\"seconds\":0,\"month\":5,\"timezoneOffset\":-540,\"year\":123,\"minutes\":0,\"time\":1687507200000,\"day\":5},\"expire_day\":0,\"regdate\":{\"date\":22,\"hours\":15,\"seconds\":27,\"month\":5,\"timezoneOffset\":-540,\"year\":123,\"minutes\":57,\"time\":1687417047000,\"day\":4},\"totalWeight\":0,\"app_nm\":\"\",\"album_id\":\"0\",\"lastupdate\":{\"date\":22,\"hours\":15,\"seconds\":27,\"month\":5,\"timezoneOffset\":-540,\"year\":123,\"minutes\":57,\"time\":1687417047000,\"day\":4},\"view_end_date\":{\"date\":30,\"hours\":17,\"seconds\":0,\"month\":5,\"timezoneOffset\":-540,\"year\":123,\"minutes\":0,\"time\":1688112000000,\"day\":5},\"category\":\"WBUGS_HEADER_COMMON_BANNER\",\"status\":\"OK\"},{\"image_bg_color\":\"\",\"clickCount\":0,\"artist\":null,\"sub_category\":\"main\",\"crt_dt\":\"\",\"db_sts\":\"\",\"link\":\"https://music.bugs.co.kr/radio/musiccast/episode/31146\",\"view_target\":\"ALL\",\"title\":\"이주연의 영화 속 음악 197화\",\"str_content_id\":\"0\",\"content_type\":\"NONE\",\"crt_id\":\"\",\"track\":null,\"view_env\":\"SVC\",\"content_id2\":\"\",\"pay_yn\":\"\",\"banner_id\":108631,\"content_id\":0,\"album\":null,\"upd_dt\":\"\",\"mv\":null,\"weight\":20,\"image_path2\":\"\",\"artist_id\":\"0\",\"mobile_target\":\"\",\"target\":\"_self\",\"upd_id\":\"\",\"wiselog_code\":\"\",\"file_ext\":\"\",\"css_class_nm\":\"\",\"image_path\":\"//image.bugsm.co.kr/banner/images/original/631/108/0/108631.jpg\",\"view_start_date\":{\"date\":22,\"hours\":17,\"seconds\":0,\"month\":5,\"timezoneOffset\":-540,\"year\":123,\"minutes\":0,\"time\":1687420800000,\"day\":4},\"expire_day\":0,\"regdate\":{\"date\":22,\"hours\":11,\"seconds\":52,\"month\":5,\"timezoneOffset\":-540,\"year\":123,\"minutes\":38,\"time\":1687401532000,\ ...
#
# 		if(headerCommonBanner != ""){
# 			window._headerCommonBannerMainList = bugs.utils.parseJson(headerCommonBanner.split("||")[0]);
# 			window._headerCommonBannerSubList = bugs.utils.parseJson(headerCommonBanner.split("||")[1]);
# 		}
#
# 		headerCommonBannerLoad(location.href);
#
# 		if(bugs.cookie.get("hasCouponEmailID") == "1"){
# 			$("#no_coupon_text").append('<a href="http://help.bugs.co.kr/sub?target=bugs/faq/list%3FfaqId%3D26048%26categoryNo%3D4600" class="linkFAQ" target="_blank">구매한 이용권이 보이지 않는다면?</a>');
# 		}
# 	});
#
# 	function popWebPlayerNotification() {
# 		var flag = Cookies.get("wpn");
# 		if(!flag)
# 			$(".slogan .tip").show();
# 		else
# 			$(".slogan .tip").hide();
# 	};
#
# 	function closeWebPlayerNotification() {
# 		Cookies.set("wpn", "Y", {expires:365*50, path:"/", domain:document.domain});
# 		$(".slogan .tip").hide();
# 	}
#
# 	function headerCommonBannerLoad(url){
# // 		url = window.location.href; //테스트용
#
# 		if(url.indexOf("?") > 0){
# 			url = url.substring(0,url.indexOf("?"))
# 		}
#
# 		if(url == g_urlWww || url == g_urlWww+"/" || url == g_urlWww+"/index" || url == g_urlMusic){ //main
# 			if(typeof window._headerCommonBannerSubList != "undefined" && window._headerCommonBannerMainList.length > 0){
# 				var selectedBanner = bugs.utils.getBannerRandomExtractByWeight(window._headerCommonBannerMainList);
# 				$('#header div.header div.banner').empty();
# 				$('#header div.header div.banner').append('<a href="'+ bugs.common_util.setLinkUrlWiseLog(selectedBanner.link, "M_header_03_03") +'" target="'+selectedBanner.target+'" onclick="bugs.logging.banner('+selectedBanner.banner_id+','+"'banner'"+')" title="'+selectedBanner.title+'-페이지 이동">'+
# 						'<img src="'+selectedBanner.image_path+'" alt="'+selectedBanner.title+'"></a>');
# 			}
#
# 		}else{ //sub
# 			if(typeof window._headerCommonBannerSubList != "undefined" && window._headerCommonBannerSubList.length > 0){
# 				var selectedBanner = bugs.utils.getBannerRandomExtractByWeight(window._headerCommonBannerSubList);
# 				$('#header div.header div.banner').empty();
# 				$('#header div.header div.banner').append('<a href="'+selectedBanner.link+'" target="'+selectedBanner.target+'" onclick="bugs.logging.banner('+selectedBanner.banner_id+','+"'banner'"+')" title="'+selectedBanner.title+'-페이지 이동">'+
# 						'<img src="'+selectedBanner.image_path+'" alt="'+selectedBanner.title+'"></a>');
# 			}
# 		}
#
# 	};
#
# </script>
# <header id="header">
# <aside class="layer layerSettingPlayer guide title" style="display:none;">
# <div class="box-shadow"></div>
# <header class="layer-title">
# <h1>안내</h1>
# </header>
# <section class="layerContents">
# <p class="message">
# 			음악을 재생할 플레이어를 선택해 주세요. <br/>
# 			벅스 웹상단 &gt; <strong>플레이어 선택</strong>에서 플레이어를 변경할 수 있습니다.
# 		</p>
# <fieldset>
# <div class="radioChk"><input checked="checked" id="radio_player_web2" name="radio_player_type2" type="radio" value="WEB"/> <label for="radio_player_web2">웹 플레이어</label></div>
# <div class="radioChk"><input id="radio_player_mac2" name="radio_player_type2" type="radio" value="MAC"/> <label for="radio_player_mac2">벅스 플레이어 (프로그램 설치 필요)</label>
# <p>
# 					v 1.3.0 미만인 경우,  최신 버전으로 업데이트 해주세요.<br/>
# <a href="https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer" target="_blank">[설치 안내 바로가기]</a>
# </p>
# </div>
# </fieldset>
# <p class="agreeCheck">
# <input id="setPlayerSelectionConfirm" name="setPlayer" type="checkbox"/> <label for="setPlayerSelectionConfirm">항상 선택한 플레이어로 재생</label>
# </p>
# <p class="btns">
# <button class="btnNormal" type="ok">확인</button>
# </p>
# </section>
# <button class="btnClose" type="cancel">닫기</button>
# </aside>
# <!-- //플레이어 선택 설정 안내 -->
# <aside class="layer layerSettingPlayer selectPlayer title" style="display:none;">
# <div class="box-shadow"></div>
# <header class="layer-title">
# <h1>플레이어 선택</h1>
# </header>
# <section class="layerContents">
# <p class="message">음악을 재생할 플레이어를 선택해 주세요.</p>
# <fieldset>
# <div class="radioChk"><input checked="checked" id="radio_player_web1" name="radio_player_type1" type="radio" value="WEB"/> <label for="radio_player_web1">웹 플레이어</label></div>
# <div class="radioChk"><input id="radio_player_mac1" name="radio_player_type1" type="radio" value="MAC"/> <label for="radio_player_mac1">벅스 플레이어 (프로그램 설치 필요)</label>
# <p>
# 					v 1.3.0 미만인 경우,  최신 버전으로 업데이트 해주세요.<br/>
# <a href="https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer" target="_blank">[설치 안내 바로가기]</a>
# </p>
# </div>
# </fieldset>
# <p class="btns">
# <button class="btnNormal" type="ok">확인</button>
# </p>
# </section>
# <button class="btnClose" type="cancel">닫기</button>
# </aside>
# <!-- //플레이어 선택 안내 -->
# <!--
# <aside class="layer layerPlayingPlayer" style="display:none;">
# 	<div class="box-shadow"></div>
#
# 	<section class="layerContents">
# 		<strong class="message">벅스 플레이어로 재생됩니다.</strong>
# 		<ul>
# 			<li>벅스 웹상단 &gt; 플레이어 선택에서 플레이어를 변경할 수 있습니다.</li>
# 			<li>혹시 벅스 플레이어가 실행되지 않는다면? <a href="https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer" onclick="$('.layerPlayingPlayer').hide();" target="_blank">[설치 안내 바로가기]</a></li>
# 		</ul>
# 	</section>
# </aside>
# -->
# <script type="text/javascript">
# //	var ua = navigator.userAgent;
# //	window._isMacBrowser = navigator.userAgent.search("Mac") > -1;
# //	window._isMacPlayerLinked = /Mac OS X 11_/.test(ua)
# //				|| /Mac OS X 12_/.test(ua)
# //				|| (/Mac OS X 10_/.test(ua) && !/Mac OS X 10_10/.test(ua) && !/Mac OS X 10_9/.test(ua) && !/Mac OS X 10_8/.test(ua) && !/Mac OS X 10_7/.test(ua) && !/Mac OS X 10_6/.test(ua) && !/Mac OS X 10_5/.test(ua)
# //														&& !/Mac OS X 10_4/.test(ua) && !/Mac OS X 10_3/.test(ua) && !/Mac OS X 10_2/.test(ua));
#
# 	var goServiceGuidePlayerPage = function(){
# 		if(navigator.platform.indexOf('Win') > -1){
# 			document.location.href = "https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer";
# 		}else{
# 			document.location.href = "https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer";
# 		}
# 	}
#
# 	$(document).ready(function() {
# 		showMacPlayerSelection();
# 	});
#
# 	var showMacPlayerSelection = function() {
# 		if(bugs.music.isMacPlayerSupport()) {
# 			$(".slogan .selectPlayer").show();
# 			$(".slogan .bugsPlayer").hide();
#
# 			var dp = bugs.cookie.get('defaultPlayer') || "";
#
# 			updateHeaderPlayerMenu(dp);
# 		} else {
# 			$(".slogan .selectPlayer").hide();
# 			$(".slogan .bugsPlayer").show();
# 		}
# 	}
#
# 	var updateHeaderPlayerMenu = function(type) {
# 		$("#headerWebPlayer").hide();
# 		$("#headerMacPlayer").hide();
#
# 		if(type == "MAC") {
# 			$("#headerMacPlayer").show();
# 		} else { // if(type == "" || type == "WEB") {
# 			$("#headerWebPlayer").show();
# 			$("#headerWebPlayer").removeAttr("onclick");
# 			$("#headerWebPlayer").unbind("click").bind("click", function() {
# 				bugs.music.popWebPlayer();
# 				bugs.wiselog.area('M_header_02_20');
# 				return false;
# 			});
# 		}
# 	}
# </script>
# <div class="top">
# <div class="slogan">
# <a class="supersound" href="https://music.bugs.co.kr/event/promotion/supersound/index?wl_ref=M_header_02_01" target="_blank">슈퍼사운드 벅스</a>
# <a aria-label="새창" class="openPlayer" href="javascript:;" id="headerWebPlayer" onclick="javascript:bugs.music.popWebPlayer();bugs.wiselog.area('M_header_02_13');return false;">웹 플레이어</a>
# <a class="openPlayer" href="bugs3://app/wakeup" id="headerMacPlayer" onclick="bugs.wiselog.area('M_header_02_18');" style="display:none;">벅스 플레이어</a>
# <span class="bugsPlayer" style="">
# <a href="javascript:;" onclick="try{bugs.wiselog.area('M_header_02_14');}catch(e){} goServiceGuidePlayerPage();">벅스 플레이어</a>
# </span>
# <a aria-label="새창" class="selectPlayer" href="javascript:;" onclick="bugs.ui.showPlayerSettingLayer();bugs.wiselog.area('M_header_02_19');" style="display:none;">플레이어 선택</a>
# </div>
# <div class="rightGroup">
# <div class="more">
# <a href="http://help.bugs.co.kr" onclick="try{bugs.wiselog.area('M_header_02_06');}catch(e){}">고객센터</a>
# <a class="game" href="javascript:;" onclick="try{bugs.wiselog.area('M_header_02_08');}catch(e){}bugs.ui.cp.headerGameMenuToggle();">게임</a>
# <aside class="layer gameMenu">
# <div class="box-shadow"></div>
# <ul class="list-layer-select">
# <li><a href="https://game.bugs.co.kr?wl_ref=sub_gnb&amp;wl_ref=M_header_02_11" onclick="try{bugs.wiselog.area('M_header_02_11');}catch(e){}" target="_blank">피망</a></li>
# </ul>
# </aside>
# </div>
# <div class="family">
# <a class="comico" href="https://www.comico.kr" onclick="try{bugs.wiselog.area('M_header_02_03');}catch(e){}" target="_blank">comico</a>
# <a class="ticketlink" href="http://www.ticketlink.co.kr" onclick="try{bugs.wiselog.area('M_header_02_04');}catch(e){}" target="_blank">티켓링크</a>
# <a class="hangame" href="https://www.hangame.com" onclick="try{bugs.wiselog.area('M_header_02_05');}catch(e){}" target="_blank">HANGAME</a>
# </div>
# </div>
# </div>
# <div class="header">
# <a class="logo seasonal hyrend" href="https://music.bugs.co.kr?wl_ref=M_header_03_01">Bugs!<span class="blind">-홈으로 이동</span></a>
# <div class="innerContainer">
# <input id="_hsi" type="hidden" value=""/>
# <fieldset class="searchForm" id="hederSearchForm">
# <div class="input">
# <input autocomplete="off" id="headerSearchInput" title="검색어 입력" type="text"/><span class="adKeywordDelete" id="keywordClearButton"><span class="blind">검색어 삭제</span></span><button class="btnSearch" id="hederSearchFormButton" onclick="bugs.search.searchFromButton();">검색<span class="blind">-페이지 이동</span></button>
# </div>
# <div id="suggest" style="display:none;">
# <div class="box-shadow"></div>
# </div>
# </fieldset>
# <div class="banner"><a href="https://music.bugs.co.kr/musicpost/UR7DS3IJ57W31V4XZG3R" onclick="bugs.logging.banner(108753,'banner')" target="_self" title="주간핫이슈 - 유다빈밴드-페이지 이동"><img alt="주간핫이슈 - 유다빈밴드" src="//image.bugsm.co.kr/banner/images/original/753/108/0/108753.jpg"/></a></div>
# </div>
# <div class="rightSection">
# <div class="member">
# <div class="login" id="loginHeader">
# <!-- <a href="javascript:bugs.ui.showLoginLayerForHeader();" onclick="javascript:bugs.wiselog.area('M_header_03_05');">로그인</a>
# 			<a href="https://secure.bugs.co.kr/member/join/memberMain?wl_ref=M_header_03_06" class="signup"><span class="bar"></span> 회원가입<span class="blind">-페이지 이동</span></a> -->
# <a href="javascript:void(0);" onclick="bugs.wiselog.area('M_header_03_05');bugs.ui.showLoginLayerForHeader({caller:this});">로그인 / 회원가입</a>
# </div>
# <div class="notification" id="memberNotificationArea">
# <button id="btnNotificationMain" onclick="bugs.notice.pop(this, g_isLogged);bugs.wiselog.area('M_header_03_04');" style="">알림</button>
# <button class="count" id="aNotificationMain" onclick="bugs.notice.pop(this, g_isLogged);bugs.wiselog.area('M_header_03_04');" style="display:none;"><span class="blind">새로운</span><span>알림</span>0<span class="blind">개</span></button>
# </div>
# </div>
# </div>
# </div>
# </header><script type="text/javascript">
# 	$(window).load(function(){
# 		if(g_isLogged){
# 			bugs.music.myAlbumList.gnbListArea = $("#gnbMyalbumListArea");
# 			bugs.music.myAlbumList.moreView = $("#btnMyalbumMoreView");
# 			bugs.music.myAlbumList.getGnbMyAlbumList(1);
# 		}
# 	});
# </script>
# <div id="gnb" style="left: 0px; height: 744px;">
# <span class="btnMenuFolding open" id="gnbHandleBtn" status="open" style="">MENU</span>
# <div class="jspScrollable" id="gnbBody" style="overflow: hidden; padding: 0px; height: 744px; width: 219px;" tabindex="0">
# <div class="jspContainer" style="width: 219px; height: 744px;"><div class="jspPane" style="padding: 0px; top: 0px; left: 0px; width: 219px; margin-left: 0px;"><div class="links">
# <div class="inner">
# <a class="btnNormal lounge" href="https://music.bugs.co.kr/member/vipinfo?wl_ref=M_header_02_12">벅스 VIP 멤버십 안내</a>
# <a class="link ticket" href="https://music.bugs.co.kr/pay/recommend?wl_ref=M_left_01_01">이용권 구매</a>
# <a class="link coupon" href="https://music.bugs.co.kr/pay/offlineCoupon?wl_ref=M_left_01_01">상품권 등록</a>
# </div>
# </div><nav>
# <ul>
# <li class="chart"><a class="hyrend selected" href="https://music.bugs.co.kr/chart?wl_ref=M_left_02_01" lmid="lm_chart">벅스차트</a></li>
# <li class="news"><a class="hyrend" href="https://music.bugs.co.kr/newest?wl_ref=M_left_02_03" lmid="lm_news">최신 음악</a></li>
# <li class="music4u"><a class="hyrend" href="https://music.bugs.co.kr/music4u?wl_ref=M_left_02_02" lmid="lm_m4u" loginrequired="PAGE">뮤직4U</a></li>
# <li class="genre"><a class="hyrend" href="https://music.bugs.co.kr/genre/home?wl_ref=M_left_02_06" lmid="lm_genre">장르</a></li>
# <li class="special"><a class="hyrend" href="https://music.bugs.co.kr/musicpost?wl_ref=M_left_02_08" lmid="lm_special">뮤직포스트</a></li>
# <li class="theme open" folder="2">
# <strong>테마</strong><span class="bu"></span>
# <ul>
# <li><a class="hyrend" href="https://music.bugs.co.kr/musicpd?wl_ref=M_left_02_04" lmid="lm_esalbum">뮤직PD 앨범</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/recomreview?wl_ref=M_left_02_05" lmid="lm_recomreview">추천앨범 리뷰</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/years?wl_ref=M_left_02_07" lmid="lm_years">연도별</a></li>
# </ul>
# </li>
# <li class="connect"><a class="hyrend" href="https://music.bugs.co.kr/connect?wl_ref=M_left_02_13" lmid="lm_connect">커넥트</a></li>
# <li class="radio"><a class="hyrend" href="https://music.bugs.co.kr/radio?wl_ref=M_left_02_10" lmid="lm_radio">라디오</a></li>
# <li class="bugsonTV open" folder="5">
# <strong>벅스TV</strong><span class="bu"></span>
# <ul>
# <li class="specialLive"><a href="https://music.bugs.co.kr/musicpost/list/bugstv?wl_ref=M_left_04_04">스페셜 라이브</a></li>
# </ul>
# </li>
# <li class="mymusic open" folder="3">
# <strong>내 음악</strong><span class="bu"></span>
# <ul>
# <li><a class="hyrend" href="https://music.bugs.co.kr/user/library/listen?wl_ref=M_left_03_05" lmid="lm_recentTrack" loginrequired="PAGE">최근 들은 곡</a> <button aria-label="새창" onclick="bugs.music.myAlbumList.listenListenedList('',true);">최근 들은 곡 재생</button></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/user/library/listen?sort=LISTEN_COUNT&amp;wl_ref=M_left_03_06" lmid="lm_manytimesTrack" loginrequired="PAGE">가장 많이 들은 곡</a> <button aria-label="새창" onclick="bugs.music.myAlbumList.listenListenedList('LISTEN_COUNT',true);">가장 많이 들은 곡 재생</button></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/user/library/purchased/track?wl_ref=M_left_03_01" lmid="lm_buymusic" loginrequired="PAGE">구매한 음악</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/user/library/like/track?wl_ref=M_left_03_02" lmid="lm_likemusic" loginrequired="PAGE">좋아한 음악</a></li>
# </ul>
# <div class="myalbum">
# <strong>내 앨범</strong>
# <a class="edit hyrend" href="https://music.bugs.co.kr/user/library/myalbum/list?wl_ref=M_left_03_07" lmid="lm_myAlbumManage" loginrequired="PAGE">전체보기</a>
# <div class="btnNewAlbum"><a href="javascript:;" onclick="playlists.make2('GNB');bugs.wiselog.area('M_left_03_04');"><span class="blind">내앨범</span>+  새로 만들기</a></div>
# <ul id="gnbMyalbumListArea">
# </ul>
# <div><a class="btnMoreAlbum" href="javascript:;" id="btnMyalbumMoreView" onclick="bugs.music.myAlbumList.getNext(); bugs.wiselog.area('M_left_03_08');" style="display:none;">더보기</a></div>
# <div class="loadingFailed" id="gnbMyalbumLoadFail" style="display:none;">
# <p>내 앨범을 불러오지<br/>못했습니다.</p>
# <button onclick="bugs.music.myAlbumList.getGnbMyAlbumList(1, 'failReload');">내 앨범 불러오기</button>
# </div>
# </div>
# </li>
# </ul>
# </nav></div><div class="jspVerticalBar" style="display:none;"><div class="jspCap jspCapTop"></div><div class="jspTrack" style="height: 744px;"><div class="jspDrag" style="height: 643px;"><div class="jspDragTop"></div><div class="jspDragBottom"></div></div></div><div class="jspCap jspCapBottom"></div></div></div></div>
# </div>
# <script>
# try{
# 	bugs.navigator.setLeftMenuFolder();
# }
# catch(e){}
# </script>
# <div id="hyrendContentBody" style="padding-left: 220px; height: 7512px;">
# <article class="mnWhatshot mnChart pgChartTrack" id="container">
# <header class="sectionPadding pgTitle">
# <div class="innerContainer">
# <h1>벅스차트</h1>
# <script type="text/javascript">
#   var toggleNationLayer = function() {
#     $("aside.selectNation").toggle(250, function(){});
#   }
#
# $(document).ready(function () {
#
#   function changeTitle(){
#     try{
#               if('KR' != 'KR'){
#         var newTitle = '벅스차트 > 곡 차트 > 대한민국 - 벅스';
#         var curTitle = document.title;
#         if(newTitle != curTitle){
#           document.title = newTitle;
#         } else {
#           setTimeout(changeTitle, 500);
#         }
#       }
#     } catch(e){}
#   };
#
#   changeTitle();
#
#   $(document).click(function(ev){
#     if( typeof($(ev.target).attr('class')) === 'undefined' ) return;
#     if ($(ev.target).attr('class') != "selectedNationName"
#         && ($(ev.target).attr('class').indexOf("flag") != 0  )
#         && ($(ev.target).attr('class').indexOf("btnNation") == -1 ) ) {
#           $("aside.selectNation").hide(250);
#       }
#     });
# });
# </script>
# <aside class="layer selectNation">
# <div class="box-shadow"></div>
# <h1>국가선택</h1>
# <ul>
# <li><a class="hyrend selected KR" href="https://music.bugs.co.kr/chart/track/realtime/total?nation=KR" onclick="bugs.wiselog.area('chart_nation_KR');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/KR.png"/></span><em class="selectedNationName">대한민국</em></a></li>
# <li><a class="hyrend nl" href="https://music.bugs.co.kr/chart/track/week/total?nation=nl" onclick="bugs.wiselog.area('chart_nation_nl');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/NL.png"/></span><em class="selectedNationName">네덜란드</em></a></li>
# <li><a class="hyrend dk" href="https://music.bugs.co.kr/chart/track/week/total?nation=dk" onclick="bugs.wiselog.area('chart_nation_dk');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/DK.png"/></span><em class="selectedNationName">덴마크</em></a></li>
# <li><a class="hyrend de" href="https://music.bugs.co.kr/chart/track/week/total?nation=de" onclick="bugs.wiselog.area('chart_nation_de');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/DE.png"/></span><em class="selectedNationName">독일</em></a></li>
# <li><a class="hyrend us" href="https://music.bugs.co.kr/chart/track/week/total?nation=us" onclick="bugs.wiselog.area('chart_nation_us');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/US.png"/></span><em class="selectedNationName">미국</em></a></li>
# <li><a class="hyrend be" href="https://music.bugs.co.kr/chart/track/week/total?nation=be" onclick="bugs.wiselog.area('chart_nation_be');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/BE.png"/></span><em class="selectedNationName">벨기에</em></a></li>
# <li><a class="hyrend br" href="https://music.bugs.co.kr/chart/track/week/total?nation=br" onclick="bugs.wiselog.area('chart_nation_br');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/BR.png"/></span><em class="selectedNationName">브라질</em></a></li>
# <li><a class="hyrend se" href="https://music.bugs.co.kr/chart/track/week/total?nation=se" onclick="bugs.wiselog.area('chart_nation_se');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/SE.png"/></span><em class="selectedNationName">스웨덴</em></a></li>
# <li><a class="hyrend es" href="https://music.bugs.co.kr/chart/track/week/total?nation=es" onclick="bugs.wiselog.area('chart_nation_es');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/ES.png"/></span><em class="selectedNationName">스페인</em></a></li>
# <li><a class="hyrend ar" href="https://music.bugs.co.kr/chart/track/week/total?nation=ar" onclick="bugs.wiselog.area('chart_nation_ar');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/AR.png"/></span><em class="selectedNationName">아르헨티나</em></a></li>
# <li><a class="hyrend gb" href="https://music.bugs.co.kr/chart/track/week/total?nation=gb" onclick="bugs.wiselog.area('chart_nation_gb');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/GB.png"/></span><em class="selectedNationName">영국</em></a></li>
# <li><a class="hyrend it" href="https://music.bugs.co.kr/chart/track/week/total?nation=it" onclick="bugs.wiselog.area('chart_nation_it');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/IT.png"/></span><em class="selectedNationName">이탈리아</em></a></li>
# <li><a class="hyrend ca" href="https://music.bugs.co.kr/chart/track/week/total?nation=ca" onclick="bugs.wiselog.area('chart_nation_ca');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/CA.png"/></span><em class="selectedNationName">캐나다</em></a></li>
# <li><a class="hyrend fi" href="https://music.bugs.co.kr/chart/track/week/total?nation=fi" onclick="bugs.wiselog.area('chart_nation_fi');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/FI.png"/></span><em class="selectedNationName">핀란드</em></a></li>
# <li><a class="hyrend fr" href="https://music.bugs.co.kr/chart/track/week/total?nation=fr" onclick="bugs.wiselog.area('chart_nation_fr');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/FR.png"/></span><em class="selectedNationName">프랑스</em></a></li>
# <li><a class="hyrend au" href="https://music.bugs.co.kr/chart/track/week/total?nation=au" onclick="bugs.wiselog.area('chart_nation_au');"><span class="flag"><img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/AU.png"/></span><em class="selectedNationName">호주</em></a></li>
# </ul>
# </aside>
# <a class="btnGenre" href="javascript:;" onclick="bugs.wiselog.area('S_gfilter_01');toggleGenreLayer();"><em class="selectedGenreName">전체 장르</em></a>
# <script type="text/javascript">
# 	<!--
# 	var toggleGenreLayer = function() {
# 		$("aside.selectGenre").toggle(250, function(){});
# 		$('aside.coachBside').hide();
# 	}
#
# 	var setSelectedType = function(selectedType) {
# 		if (selectedType == "") selectedType = "total";
# 				$('ul.listGenre > li > a').each(function(index) {$(this).removeClass('selected')});
# 		$('ul.listGenre > li[type='+selectedType+'] > a').addClass('selected');
# 	}
#
# 		jQuery(document).ready(function () {
# 			setSelectedType("total");
#
# 			$(document).click(function(ev){
# 				try{
# 					if( typeof($(ev.target).attr('class')) === 'undefined' ) return;
# 					if ($(ev.target).attr('class') != "selectedGenreName"
# 						&& ($(ev.target).attr('class').indexOf("btnGenre") == -1) ) {
# 						$("aside.selectGenre").hide(250);
# 					}
# 				}catch(e){}
# 			});
# 		});
# 	//-->
# 	</script>
# <!-- 장르선택 레이어 -->
# <aside class="layer selectGenre">
# <div class="box-shadow"></div>
# <h1>장르선택</h1>
# <ul class="category">
# <li>
# <em class="all">전체</em>
# <ul class="listGenre">
# <li type="total"><a class="hyrend selected" href="https://music.bugs.co.kr/chart/track/realtime/total">전체 장르</a></li>
# <li type="kpop"><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/kpop">국내 전체 장르</a></li>
# <li type="pop"><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/pop">해외 전체 장르</a></li>
# </ul>
# </li>
# <li>
# <em class="domestic">국내</em>
# <ul class="listGenre">
# <li type="nb"><a class="hyrend" data-category="domestic" href="https://music.bugs.co.kr/chart/track/day/nb">발라드</a></li>
# <li type="ndp"><a class="hyrend" data-category="domestic" href="https://music.bugs.co.kr/chart/track/day/ndp">댄스/팝</a></li>
# <li type="nfa"><a class="hyrend" data-category="domestic" href="https://music.bugs.co.kr/chart/track/day/nfa">포크/어쿠스틱</a></li>
# <li type="nid"><a class="hyrend" data-category="domestic" href="https://music.bugs.co.kr/chart/track/day/nid">아이돌</a></li>
# <li type="nrh"><a class="hyrend" data-category="domestic" href="https://music.bugs.co.kr/chart/track/day/nrh">랩/힙합</a></li>
# <li type="nrs"><a class="hyrend" data-category="domestic" href="https://music.bugs.co.kr/chart/track/day/nrs">알앤비/소울</a></li>
# ...
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6199216');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6199216');
# " track_title="부동의 첫사랑">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6199216','true','true','44.1','false','', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6199216, 616895, 'Y', 'Y', 'Y', 'Y', 6199216, 'N','ALL', 'Y');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="10CM" artist_id="80067149" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6199216','0','4086496','bugs.music.listenRadioFromSeed(\'6199216\',\'track\');','N', 'Y', '_chart');
# " track_title="부동의 첫사랑">기타 기능</a>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="pageAdditionalInfo">
# <ul>
# <li><span class="icon"></span>집계기간 내 듣기와 다운로드 수 합산하여 반영</li>
# </ul>
# </div>
# <script>
# $(document).ready(function(){
# 		var contentsBanner = '[]';
#
# 	if(contentsBanner != "" && contentsBanner != "[]" ){
# 		contentsBanner = bugs.utils.parseJson(contentsBanner);
# 		var wiselogStr = "";
# 		for(var i = 0; i < contentsBanner.length && i < 3; i++){
# 			if(i==0){
# 				wiselogStr = "bugs.wiselog.area('S_sp_04_01');"
# 			}else if( i==1){
# 				wiselogStr = "bugs.wiselog.area('S_sp_04_02');"
# 			}else if( i==2){
# 				wiselogStr = "bugs.wiselog.area('S_sp_04_03');"
# 			}
# 			$('#contentsBanner'+(i+1)).empty();
# 			$('#contentsBanner'+(i+1)).append('<a href="'+contentsBanner[i].link+'" target="'+contentsBanner[i].target+
# 					'" onclick="'+wiselogStr+'bugs.logging.banner('+contentsBanner[i].banner_id+','+"'banner'"+')" title="'+contentsBanner[i].title+'-페이지 이동">'+
# 											'<img src="'+contentsBanner[i].image_path+'" alt="'+contentsBanner[i].title+'"></a>');
# 		}
#
# 		var oldWidth = $(window).width();
# 		if(oldWidth < 1903){
# 			$('#contentsBanner2').addClass('lineBreak');
# 		}else{
# 			$('#contentsBanner3').addClass('lineBreak');
# 		}
# 		var currentWidth = 0;
# 		$(window).on('resize',function(){
# 			currentWidth = $(window).width();
# 			if(oldWidth < 1903 && 1903 <= currentWidth){
# 				$('#contentsBanner2').removeClass('lineBreak');
# 				$('#contentsBanner3').addClass('lineBreak');
# 			}else if(currentWidth < 1903 && 1903 <= oldWidth){
# 				$('#contentsBanner3').removeClass('lineBreak');
# 				$('#contentsBanner2').addClass('lineBreak');
# 			}
# 			oldWidth = currentWidth;
# 		});
#
# 		$('aside.contentsBanner').show();
# 	}
#
# });
# </script>
# <aside class="contentsBanner" style="display:none;">
# <ul class="listContentsBanner">
# <li id="contentsBanner1">
# </li>
# <li id="contentsBanner2">
# </li>
# <li id="contentsBanner3">
# </li>
# </ul>
# </aside>
# </div>
# </section>
# <!-- 레이어 - 실시간  -->
# <aside class="layer layer-select realtime" style="top: 165px;left: 600px;display:block;visibility:hidden;">
# <div class="box-shadow"></div>
# <h1>선택 레이어</h1>
# <div class="innerScroll jspScrollable" style="overflow: hidden; padding: 0px; width: 138px;" tabindex="0">
# <div class="jspContainer" style="width: 138px; height: 340px;"><div class="jspPane" style="padding: 0px; margin-left: 0px; top: 0px; width: 138px;"><ul class="list-layer-select center">
# <li><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20230627&amp;charthour=15">15:00</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20230627&amp;charthour=14">14:00</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20230627&amp;charthour=13">13:00</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20230627&amp;charthour=12">12:00</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20230627&amp;charthour=11">11:00</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20230627&amp;charthour=10">10:00</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20230627&amp;charthour=09">09:00</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20230627&amp;charthour=08">08:00</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20230627&amp;charthour=07">07:00</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20230627&amp;charthour=01">01:00</a></li>
# <li><a class="hyrend" href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20230627&amp;charthour=00">00:00</a></li>
# </ul></div><div class="jspVerticalBar" style="display:none;"><div class="jspCap jspCapTop"></div><div class="jspTrack" style="height: 340px;"><div class="jspDrag" style="height: 310px;"><div class="jspDragTop"></div><div class="jspDragBottom"></div></div></div><div class="jspCap jspCapBottom"></div></div></div></div>
# </aside>
# </article>
# </div>
# <div class="floatingTop">
# <a class="btnTop" href="javascript:void(bugs.navigator.scrollTop())">TOP</a>
# </div>
# <script src="/js/jquery/jquery-dateFormat.min.js" type="text/javascript"></script>
# <script>
# $(window.document).ready(function() {
# 			setTimeout(function(){
# 				$.ajax({
# 					url : g_urlAjax + "/board/notice/ajax/commonfooternotice",
# 					type : "POST",
# 					dataType : "json",
# 					success : function(data){
# 						if(data != null){
# 							$("#commonFooterNotice a#commonFooterNoticeTitle").text(data.title);
# 							$("#commonFooterNotice a#commonFooterNoticeTitle").attr("href", g_urlMusic + "/board/notice?srl=" + data.srl + "&wl_ref=M_footer_01_01");
# 							$("#commonFooterNotice time").text(data.str_crt_dt);
# 							$("#commonFooterNotice time").attr("datetime", $.format.date(Date.parse(data.str_crt_dt,"yyyy.MM.dd"), "yyyy-MM-dd"));
# 						}
# 					}
# 				});
# 			}, 1300);
#
# });
# </script>
# <script src="/js/bugs/bugs.footer.layer.js" type="text/javascript"></script>
# <footer id="footer" style="padding-left: 220px;">
# <section class="sectionPadding">
# <div class="innerContainer">
# <div class="notice" id="commonFooterNotice">
# <strong><a href="https://music.bugs.co.kr/board/notice?wl_ref=M_footer_01_01">공지사항</a></strong>
# <a href="https://music.bugs.co.kr/board/notice?srl=3037&amp;wl_ref=M_footer_01_01" id="commonFooterNoticeTitle">[당첨자발표] ♥Bugs Favorite♥ BOYNEXTDOOR [WHO!] 이벤트</a>
# <time datetime="2023-06-27">2023.06.27</time>
# </div>
# <div class="quicklinks">
# <ul>
# <li><a href="https://music.bugs.co.kr/event?wl_ref=M_footer_02_01">이벤트</a></li>
# <li><a href="https://music.bugs.co.kr/panel?wl_ref=M_footer_02_01">벅스패널</a></li>
# </ul>
# <ul>
# <li><a href="https://music.bugs.co.kr/serviceGuide/home?wl_ref=M_footer_02_07">벅스 꿀팁 보기</a></li>
# </ul>
# </div>
# </div>
# </section>
# <section class="sectionPadding contents">
# <div class="innerContainer">
# <ul class="links">
# <li><a href="http://www.bugscorp.co.kr?wl_ref=M_footer_03_01" target="_blank">회사소개</a></li>
# <li><a href="https://music.bugs.co.kr/cooperation?wl_ref=M_footer_03_01">제휴문의</a></li>
# <li><a href="https://music.bugs.co.kr/rules/use?wl_ref=M_footer_03_01">이용약관</a></li>
# <li><a href="https://music.bugs.co.kr/rules/privacy?wl_ref=M_footer_03_01"><em>개인정보처리방침</em></a></li>
# <li><a href="https://music.bugs.co.kr/rules/youth?wl_ref=M_footer_03_01">청소년보호정책</a></li>
# <li><a href="https://music.bugs.co.kr/connect/center?wl_ref=M_footer_03_01">커넥트 센터</a></li>
# <li><a href="http://help.bugs.co.kr?wl_ref=M_footer_03_01">고객센터</a></li>
# <li><a href="https://music.bugs.co.kr/sitemap?wl_ref=M_footer_03_01">사이트맵</a></li>
# <li><a href="https://inside.nhn.com/br/index.nhn" target="_blank">NHN 브랜드 사이트</a></li>
# </ul>
# <aside>
# <div class="sns">
# <a class="blog" href="https://blog.naver.com/blog_bugs" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">블로그</a>
# <a class="facebook" href="https://www.facebook.com/bugsplay" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">페이스북</a>
# <a class="kakaostory" href="https://story.kakao.com/ch/bugs" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">카카오스토리</a>
# </div>
# <div class="familysite">
# <button onclick="bugs.ui.cp.footerFamilySiteMenu(this);" tabindex="0">FAMILY SITE</button>
# <aside class="layer familysiteMenu">
# <div class="box-shadow"></div>
# <ul class="list-layer-select">
# <li><a href="http://www.nhn.com" onclick="if(bugs.wiselog.area) {bugs.wiselog.area('M_fotter_03_01');}" target="_blank">NHN</a></li>
# <li><a href="http://me.sayclub.com" onclick="if(bugs.wiselog.area) {bugs.wiselog.area('M_fotter_03_01');}" target="_blank">세이클럽</a></li>
# </ul>
# </aside>
# </div>
# </aside>
# <address>
# <span>(주)엔에이치엔벅스</span>
# <span>13487 경기도 성남시 분당구 대왕판교로 645번길 16 플레이뮤지엄</span>
# <span>대표이사 : 왕문주</span>
# <span>고객센터 : <a href="mailto:help@help.bugs.co.kr">help@help.bugs.co.kr</a> / 1566-4882 (유료)</span><br/>
# <span>사업자등록번호 : 211-87-15555</span>
# <span>통신판매업 신고번호 : 제 2013-경기성남-0532호</span>
# <span>호스팅 제공자 : (주)엔에이치엔벅스</span>
# <span><a href="http://www.ftc.go.kr/bizCommPop.do?wrkr_no=2118715555" target="_blank">사업자 정보 확인</a></span>
# <span>© NHN Bugs Corp. All rights reserved.</span>
# </address>
# <script>
#
# if (!bugs.ui.cp) {
# 	bugs.ui.cp = {
# 		headerGameMenuToggle : function() {
# 			$('.layer.gameMenu').toggle();
#
# 			if(bugs.wiselog.area) {
# 				bugs.wiselog.area('M_header_02_02');
# 			}
# 		},
# 		footerFamilySiteMenu : function() {
# 			$('.layer.familysiteMenu').toggle();
#
# 			if(bugs.wiselog.area) {
# 				bugs.wiselog.area('M_fotter_03_01');
# 			}
# 		}
# 	};
# }
#
# </script>
# <ul class="emblem">
# <li>
# <a href="https://help.bugs.co.kr/hc/notice/2586/" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">
# <img alt="Google Play 선정 2018 올해를 빛낸 앱" loading="lazy" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemGooglePlay.png"/>
# </a>
# </li>
# <li>
# <a href="https://music.bugs.co.kr/specialView/supersound/NJ6P8GAP0ERQFD84GUCF" onclick="bugs.wiselog.area('M_fotter_03_01');">
# <img alt="하이 레졸루션 공식인증" loading="lazy" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemHiRes.png"/>
# </a>
# </li>
# <li>
# <a href="https://help.bugs.co.kr/hc/notice/1933/" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">
# <img alt="2015 상반기 대학생선호브랜드 대상" loading="lazy" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemHerald.png"/>
# </a>
# </li>
# <li>
# <a href="https://help.bugs.co.kr/hc/notice/1522/" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">
# <img alt="스마트앱어워드 대상 수상" loading="lazy" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemAppaward.png"/>
# </a>
# </li>
# <li>
# <button onclick="bugs.footer.layer.showIsms();">
# <img alt="정보보호 관리체계 ISMS 인증" loading="lazy" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemISMSV202108.png"/>
# </button>
# </li>
# <li>
# <img alt="음악저작권 이용 허락 인증" loading="lazy" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemClms.png"/>
# </li>
# <li>
# <a href="https://www.kcopa.or.kr/lay1/S1T356C360/contents.do" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">
# <img alt="저작권안심" loading="lazy" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemCopyrightokV20220803.png"/>
# </a>
# </li>
# </ul>
# </div>
# </section>
# </footer>
# </div>
# <!--<a href="javascript:void(playlists.resetPlaylist())">리셋하기</a>-->
# <script type="text/javascript">
# $(document).ready(function(){
# 	try{
# 		bugs.navigator.addHyrendUnloadHandler(function(){playlists.playlistLayerHide();},"track2playlistForMoveHyrend", true);
# 	}catch(e){}
#
# });
# </script>
# <aside class="layer layer-select addMyAlbum" id="track2playlist" style="display:none;">
# <div class="box-shadow"></div>
# <h1>내 앨범 목록</h1>
# <div autoscroll="N" class="innerScroll" id="track2playlistScrollArea">
# <ul class="list-layer-select">
# <li><a href="javascript:;" onclick="$('#track2playlist').hide('blind', {}, 'normal', function() { bugs.ui.modalLayer.hide();playlists.make(); });" title="새 앨범 만들기">+ 새 앨범 만들기</a></li>
# </ul>
# </div>
# </aside>
# <!-- 레이어 - 내 앨범 수정 -->
# <aside class="layer createMyAlbum" id="editMyAlbumLayer" style="display:none; z-index:1002;">
# <div class="box-shadow"></div>
# <header class="layer-title">
# <h1>앨범 정보 수정</h1>
# </header>
# <section class="layerContents">
# <fieldset>
# <legend>내 앨범 수정</legend>
# <table class="formLayout">
# <caption>내 앨범 수정 입력 폼</caption>
# <tbody>
# <tr>
# <th scope="row"><label class="lb" for="editMyAlbumLayerPhoto">사진</label></th>
# <td>
# <img alt="" class="thumb" id="editMyAlbumLayerPhoto_img" src="https://file.bugsm.co.kr/wbugs/common/i_defaultMyAlbum_50x50.png"/>
# <div class="inputFile">
# <input class="file" diabled="" id="editMyAlbumLayerPhoto" type="text"/>
# <button class="btnNormal" id="searchImage" type="button">찾아보기</button>
# <input id="editMyAlbumLayerPhoto_path" title="사진경로" type="hidden"/>
# </div>
# </td>
# <td class="right" style="width:55px;"></td>
# </tr>
# <tr>
# <th scope="row" style="width:55px;"><label class="lb" for="editMyAlbumLayerTitle">제목</label></th>
# <td><input class="txt" id="editMyAlbumLayerTitle" type="text" value="111"/></td>
# <td class="right" style="width:55px;"><span class="remain" id="editMyAlbumLayerTitleRemain">(0/100)</span></td>
# </tr>
# <tr>
# <th scope="row"><label class="lb" for="editMyAlbumLayerDescribe">설명</label></th>
# <td>
# <textarea class="txtArea" cols="30" id="editMyAlbumLayerDescribe" name="" rows="10"></textarea>
# </td>
# <td class="right"><span class="remain" id="editMyAlbumLayerDescribeRemain">(0/300)</span></td>
# </tr>
# </tbody>
# </table>
# <p class="btns">
# <button btntype="ok" class="btnNormal" id="editMyAlbumLayerUpdate">저장</button>
# <button btntype="cancel" class="btnNormal" id="editMyAlbumLayerCancel">취소</button>
# </p>
# </fieldset>
# </section>
# <button btntype="close" class="btnClose" id="editMyAlbumLayerClose">닫기</button>
# </aside>
# <aside class="layer createMyAlbum" id="createMyAlbumLayer" style="display:none; z-index:1000;">
# <div class="box-shadow"></div>
# <header class="layer-title">
# <h1 id="createMyAlbumLayerHeader"></h1>
# </header>
# <section class="layerContents">
# <fieldset>
# <legend id="createMyAlbumLayerLegend"></legend>
# <div class="row">
# <label for="createMyAlbumLayerTitle">제목</label>
# <div class="col">
# <input class="txt" id="createMyAlbumLayerTitle" type="text" value=""/>
# <span class="remain" id="createMyAlbumLayerTitleRemain">(0/100)</span>
# </div>
# </div>
# <div class="btns">
# <button btntype="ok" class="btnNormal strong" id="createMyAlbumLayerUpdate">저장</button>
# <button btntype="cancel" class="btnNormal" id="createMyAlbumLayerCancel">취소</button>
# </div>
# </fieldset>
# </section>
# <button btntype="close" class="btnClose" id="crerateMyAlbumLayerClose">닫기</button>
# </aside>
# <span id="removeSpecialCharTarget" style="display:none;"></span>
# <script>
# try{
# 	bugs.navigator.setLeftMenuShowOnLoad();
# }
# catch(e){}
# $(document).ready(function(){
# 	var isFirefox = navigator.userAgent.toLowerCase().indexOf('firefox') > -1;
# 	if(isFirefox){
# 		$("#skipNav").css({top:"1px", left:"1px"});
# 	}
# });
# </script>
# <!-- 470517  -->
# <script>
# try {
# 		var expTime = (new Date()).getTime() + (60*60*24*30*1000);
# 	var expTime2 = (new Date()).getTime() - (60*5*1000);
# 	    bugs.cookie.set("last_login_log_date_cookie","", expTime2, "/", "bugs.co.kr");
# }
# catch(e){}
# </script>
# <!-- 공통 적용 스크립트 , 모든 페이지에 노출되도록 설치. 단 전환페이지 설정값보다 항상 하단에 위치해야함 -->
# <script src="//wcs.naver.net/wcslog.js" type="text/javascript"> </script>
# <script type="text/javascript">
#     if (!wcs_add) var wcs_add={};
#     wcs_add["wa"] = "s_595467f7a42";
#     if (!_nasa) var _nasa={};
#     wcs.inflow("bugs.co.kr");
#     wcs_do(_nasa);
# </script>
# <div class="fb_reset" id="fb-root"><div style="position: absolute; top: -10000px; width: 0px; height: 0px;"><div></div></div></div></body></html>

# %%
songs = soup.select('table > tbody > tr')
len(songs)
# Out:
# 100

# %%
song = soup.select

# %%
songs[8].select('span > a')[0].text
# Out:
# '우리들의 블루스'

# %%
result = []
for song in songs:
    rank = song.select('span.rank')[0].text
    # rankupdn = song.select('span.rank_wrap > span.up')
    title = song.select('span > a')[0].text
    singer = song.select('span.checkEllipsis > a ')[0].text    
    result.append([rank, title, singer])

# %%
import pandas as pd

# %%
df = pd.DataFrame(result)
df
# Out:
#       0                                1                   2
# 0     1                   퀸카 (Queencard)             (여자)아이들
# 1     2                             I AM           IVE (아이브)
# 2     3                            Spicy               aespa
# 3     4            이브, 프시케 그리고 푸른 수염의 아내  LE SSERAFIM (르세라핌)
# 4     5  UNFORGIVEN (feat. Nile Rodgers)  LE SSERAFIM (르세라핌)
# ..  ...                              ...                 ...
# 95   96                        Shut Down           BLACKPINK
# 96   97             정이라고 하자 (Feat. 10CM)   BIG Naughty (서동현)
# 97   98                           당신을 만나                 김호중
# 98   99                   Say I Love You          우디 (Woody)
# 99  100                       Pink Venom           BLACKPINK
#
# [100 rows x 3 columns]

# %%
df.columns = ['순위', '곡명', '가수명']
df
# Out:
#      순위                               곡명                 가수명
# 0     1                   퀸카 (Queencard)             (여자)아이들
# 1     2                             I AM           IVE (아이브)
# 2     3                            Spicy               aespa
# 3     4            이브, 프시케 그리고 푸른 수염의 아내  LE SSERAFIM (르세라핌)
# 4     5  UNFORGIVEN (feat. Nile Rodgers)  LE SSERAFIM (르세라핌)
# ..  ...                              ...                 ...
# 95   96                        Shut Down           BLACKPINK
# 96   97             정이라고 하자 (Feat. 10CM)   BIG Naughty (서동현)
# 97   98                           당신을 만나                 김호중
# 98   99                   Say I Love You          우디 (Woody)
# 99  100                       Pink Venom           BLACKPINK
#
# [100 rows x 3 columns]

# %%
# 데이터프레임을 csv 저장
df.to_csv('./melon_ranking_100.csv', encoding='utf-8', index=False)

# %% [markdown]
# #### 셀레니움 만으로 크롤링

# %%
from selenium.webdriver.common.by import By

s_songs = driver.find_elements(By.XPATH, '//table/tbody/tr')

for song in s_songs:
    # print(song.text.split('\n'))
    tmp = song.text.split('\n')
    rank = tmp[0]
    title = tmp[-5]
    singer = tmp[-4]
    print(rank, title, singer)
# Out:
# 1 퀸카 (Queencard) (여자)아이들
# 2 I AM IVE (아이브)
# 3 Spicy aespa
# 4 이브, 프시케 그리고 푸른 수염의 아내 LE SSERAFIM (르세라핌)
# 5 UNFORGIVEN (feat. Nile Rodgers) LE SSERAFIM (르세라핌)
# 6 Kitsch IVE (아이브)
# 7 사랑은 늘 도망가 임영웅
# 8 헤어지자 말해요 박재정
# 9 모래 알갱이 임영웅
# 10 Hype boy NewJeans
# 11 우리들의 블루스 임영웅
# 12 다시 만날 수 있을까 임영웅
# 13 손오공 세븐틴 (SEVENTEEN)
# 14 꽃 지수 (JISOO)
# 15 Ditto NewJeans
# 16 무지개 임영웅
# 17 London Boy 임영웅
# 18 이제 나만 믿어요 임영웅
# 19 Polaroid 임영웅
# 20 아버지 임영웅
# 21 Cupid FIFTY FIFTY
# 22 인생찬가 임영웅
# 23 OMG NewJeans
# 24 A bientot 임영웅
# 25 손이 참 곱던 그대 임영웅
# 26 사랑해 진짜 임영웅
# 27 연애편지 임영웅
# 28 사건의 지평선 윤하 (YOUNHA)
# 29 I Don't Think That I Like Her Charlie Puth
# 30 Candy NCT DREAM
# 31 Dangerously Charlie Puth
# 32 Allergy (여자)아이들
# 33 파이팅 해야지 (Feat. 이영지) 부석순 (SEVENTEEN)
# 34 After LIKE IVE (아이브)
# 35 Attention NewJeans
# 36 Dynamite 방탄소년단
# 37 LOVE DIVE IVE (아이브)
# 38 보금자리 임영웅
# 39 Teddy Bear STAYC(스테이씨)
# 40 물론 허각
# 41 심(心) DK(디셈버)
# 42 사랑하지 않아서 그랬어 임한별
# 43 Butter 방탄소년단
# 44 ANTIFRAGILE LE SSERAFIM (르세라핌)
# 45 사랑..그게 뭔데 지아
# 46 Take Two 방탄소년단
# 47 사람 Pt.2 (feat. 아이유) Agust D
# 48 봄날 방탄소년단
# 49 Like Crazy 지민
# 50 사랑인가 봐 멜로망스
# 51 잠깐 시간 될까 이무진
# 52 Broken Melodies NCT DREAM
# 53 Permission to Dance 방탄소년단
# 54 나에게 그대만이 탑현
# 55 너의 모든 순간 성시경
# 56 Heaven(2023) 임재현
# 57 NIGHT DANCER imase
# 58 빛이 나는 너에게 던 (DAWN)
# 59 The Planet 방탄소년단
# 60 건물 사이에 피어난 장미 (Rose Blossom) H1-KEY (하이키)
# 61 HARD SHINee (샤이니)
# 62 사실말야내가말야그게그러니까말이야 케이시 (Kassy)
# 63 Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound) 정국, 방탄소년단
# 64 Thirsty aespa
# 65 Angel Pt. 1 (Feat. Kodak Black, NLE Choppa, JVKE, Muni Long) Fast & Furious: The Fast Saga, 지민
# 66 That's Hilarious Charlie Puth
# 67 찬란한 하루 멜로망스
# 68 KNOCK 이채연
# 69 STAY The Kid LAROI, Justin Bieber
# 70 첫 키스에 내 심장은 120BPM 경서
# 71 TOMBOY (여자)아이들
# 72 Nxde (여자)아이들
# 73 사랑의 바보 제이세라
# 74 부동의 첫사랑 10CM
# 75 해요 (2022) #안녕
# 76 취중고백 김민석 (멜로망스)
# 77 나의 바람 (Wind And Wish) 비투비
# 78 안녕이라고 말하지마 V.O.S
# 79 한사람만 (2023) (여름날 우리 X 이홍기 (FT아일랜드)) 이홍기 (FT아일랜드)
# 80 on the street (with J. Cole) j-hope, J. Cole
# 81 That’s Not How This Works (feat. Dan + Shay) Charlie Puth
# 82 사랑하기 싫어 지아
# 83 Monologue 테이
# 84 그라데이션 10CM
# 85 CHRISTIAN Zior Park
# 86 FRIEND THE END 볼빨간사춘기
# 87 사랑하지 않아서 그랬니 지아
# 88 Love Me Like This NMIXX
# 89 다정히 내 이름을 부르면 경서예지, 전건호
# 90 한강에서 (Feat. BIG Naughty) 폴킴
# 91 그중에 그대를 만나 김호중
# 92 ELEVEN IVE (아이브)
# 93 FEARLESS LE SSERAFIM (르세라핌)
# 94 Shut Down BLACKPINK
# 95 LOCKDOWN 이세계아이돌
# 96 정이라고 하자 (Feat. 10CM) BIG Naughty (서동현)
# 97 내가 아니라도 주호
# 98 Say I Love You 우디 (Woody)
# 99 Pink Venom BLACKPINK
# 100 새삥 (Prod. ZICO) (Feat. 호미들) 지코 (ZICO)

# %% [markdown]
# #### 벅스 인기차트 100 크롤링

# %%
driver = webdriver.Chrome()
driver.get('https://music.bugs.co.kr/chart')

# %%
# 벅스차트 html 가져오기
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
# 벅스 페이지 내에 table이 두개 존재하므로 table의 클래스명까지 검색해야지 차트100개만 나옴
songs = soup.select('table.byChart > tbody > tr')
print(songs)
# Out:
# [<tr albumid="4086320" artistid="20056456" multiartist="N" mvid="616921" rowtype="track" trackid="6199292">
# <input name="_isStream" type="hidden" value="6199292"/>
# <input name="_isDown" type="hidden" value="6199292"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="퀸카 (Queencard)" type="checkbox" value="6199292"/></td>
# <td>
# <div class="ranking">
# <strong>1</strong>
# <p class="change none"><em>0</em><span>변동없음</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4086320?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="I feel 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40863/4086320.jpg?version=20230615010743.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6199292?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6199292',true);
# " title="퀸카 (Queencard)">퀸카 (Queencard)</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/20056456?wl_ref=list_tr_10_chart" onclick="
# " title="(여자)아이들">(여자)아이들</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4086320?wl_ref=list_tr_11_chart" onclick="
# " title="I feel">I feel</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6199292',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6199292');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6199292');
# " track_title="퀸카 (Queencard)">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6199292','true','true','44.1','true','48', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6199292, 616921, 'Y', 'Y', 'Y', 'Y', 6199292, 'N','OVER_12', 'N');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="(여자)아이들" artist_id="20056456" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6199292','0','4086320','bugs.music.listenRadioFromSeed(\'6199292\',\'track\');','N', 'Y', '_chart');
# " track_title="퀸카 (Queencard)">기타 기능</a>
# </td>
# </tr>, <tr albumid="4084947" artistid="20148657" multiartist="N" mvid="616170" rowtype="track" trackid="6195812">
# <input name="_isStream" type="hidden" value="6195812"/>
# <input name="_isDown" type="hidden" value="6195812"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="I AM" type="checkbox" value="6195812"/></td>
# <td>
# <div class="ranking">
# <strong>2</strong>
# <p class="change none"><em>0</em><span>변동없음</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4084947?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="I've IVE 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40849/4084947.jpg?version=20230414004012.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6195812?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6195812',true);
# " title="I AM">I AM</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/20148657?wl_ref=list_tr_10_chart" onclick="
# " title="IVE (아이브)">IVE (아이브)</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4084947?wl_ref=list_tr_11_chart" onclick="
# " title="I've IVE">I've IVE</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6195812',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6195812');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6195812');
# " track_title="I AM">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6195812','true','true','44.1','true','96', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6195812, 616170, 'Y', 'Y', 'Y', 'Y', 6195812, 'N','OVER_12', 'Y');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="IVE (아이브)" artist_id="20148657" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6195812','0','4084947','bugs.music.listenRadioFromSeed(\'6195812\',\'track\');','N', 'Y', '_chart');
# " track_title="I AM">기타 기능</a>
# </td>
# </tr>, <tr albumid="4087619" artistid="80044237" multiartist="N" mvid="617825" rowtype="track" trackid="6204236">
# <input name="_isStream" type="hidden" value="6204236"/>
# <input name="_isDown" type="hidden" value="6204236"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="HARD" type="checkbox" value="6204236"/></td>
# <td>
# <div class="ranking">
# <strong>3</strong>
# <p class="change none"><em>0</em><span>변동없음</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4087619?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="HARD - The 8th Album 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40876/4087619.jpg?version=20230627012147.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6204236?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6204236',true);
# " title="HARD">HARD</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/80044237?wl_ref=list_tr_10_chart" onclick="
# " title="SHINee (샤이니)">SHINee (샤이니)</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4087619?wl_ref=list_tr_11_chart" onclick="
# " title="HARD - The 8th Album">HARD - The 8th Album</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6204236',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6204236');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6204236');
# " track_title="HARD">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6204236','true','true','44.1','false','', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6204236, 617825, 'Y', 'Y', 'Y', 'Y', 6204236, 'N','ALL', 'Y');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="SHINee (샤이니)" artist_id="80044237" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6204236','0','4087619','bugs.music.listenRadioFromSeed(\'6204236\',\'track\');','N', 'Y', '_chart');
# " track_title="HARD">기타 기능</a>
# </td>
# </tr>, <tr albumid="4085992" artistid="20158908" multiartist="N" mvid="617122" rowtype="track" trackid="6197839">
# <input name="_isStream" type="hidden" value="6197839"/>
# <input name="_isDown" type="hidden" value="6197839"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="이브, 프시케 그리고 푸른 수염의 아내" type="checkbox" value="6197839"/></td>
# <td>
# <div class="ranking">
# <strong>4</strong>
# <p class="change up"><span class="arrow"></span> <em>1</em> <span>계단 상승</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4085992?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="UNFORGIVEN 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40859/4085992.jpg?version=20230525012543.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6197839?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6197839',true);
# " title="이브, 프시케 그리고 푸른 수염의 아내">이브, 프시케 그리고 푸른 수염의 아내</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/20158908?wl_ref=list_tr_10_chart" onclick="
# " title="LE SSERAFIM (르세라핌)">LE SSERAFIM (르세라핌)</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4085992?wl_ref=list_tr_11_chart" onclick="
# " title="UNFORGIVEN">UNFORGIVEN</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6197839',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6197839');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6197839');
# " track_title="이브, 프시케 그리고 푸른 수염의 아내">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6197839','true','true','44.1','true','44.1', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6197839, 617122, 'Y', 'Y', 'Y', 'Y', 6197839, 'N','OVER_12', 'Y');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="LE SSERAFIM (르세라핌)" artist_id="20158908" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6197839','0','4085992','bugs.music.listenRadioFromSeed(\'6197839\',\'track\');','N', 'Y', '_chart');
# " track_title="이브, 프시케 그리고 푸른 수염의 아내">기타 기능</a>
# </td>
# </tr>, <tr albumid="20563467" artistid="80347326" multiartist="N" mvid="616768" rowtype="track" trackid="32845387">
# <input name="_isStream" type="hidden" value="32845387"/>
# <input name="_isDown" type="hidden" value="32845387"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="Spicy" type="checkbox" value="32845387"/></td>
# <td>
# <div class="ranking">
# <strong>5</strong>
# <p class="change down"><span class="arrow"></span> <em>1</em> <span>계단 하락</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/20563467?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="MY WORLD - The 3rd Mini Album 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/205634/20563467.jpg?version=20230601002330.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/32845387?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('32845387',true);
# " title="Spicy">Spicy</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/80347326?wl_ref=list_tr_10_chart" onclick="
# " title="aespa">aespa</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/20563467?wl_ref=list_tr_11_chart" onclick="
# " title="MY WORLD - The 3rd Mini Album">MY WORLD - The 3rd Mini Album</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('32845387',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('32845387');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'32845387');
# " track_title="Spicy">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'32845387','true','true','44.1','false','', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,32845387, 616768, 'Y', 'Y', 'Y', 'Y', 32845387, 'N','ALL', 'Y');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="aespa" artist_id="80347326" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'32845387','0','20563467','bugs.music.listenRadioFromSeed(\'32845387\',\'track\');','N', 'Y', '_chart');
# " track_title="Spicy">기타 기능</a>
# </td>
# </tr>, <tr albumid="4084947" artistid="20148657" multiartist="N" mvid="615923" rowtype="track" trackid="6194446">
# <input name="_isStream" type="hidden" value="6194446"/>
# <input name="_isDown" type="hidden" value="6194446"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="Kitsch" type="checkbox" value="6194446"/></td>
# <td>
# <div class="ranking">
# <strong>6</strong>
# <p class="change none"><em>0</em><span>변동없음</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4084947?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="I've IVE 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40849/4084947.jpg?version=20230414004012.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6194446?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6194446',true);
# " title="Kitsch">Kitsch</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/20148657?wl_ref=list_tr_10_chart" onclick="
# " title="IVE (아이브)">IVE (아이브)</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4084947?wl_ref=list_tr_11_chart" onclick="
# " title="I've IVE">I've IVE</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6194446',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6194446');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6194446');
# " track_title="Kitsch">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6194446','true','true','44.1','true','96', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6194446, 615923, 'Y', 'Y', 'Y', 'Y', 6194446, 'N','OVER_12', 'Y');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="IVE (아이브)" artist_id="20148657" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6194446','0','4084947','bugs.music.listenRadioFromSeed(\'6194446\',\'track\');','N', 'Y', '_chart');
# " track_title="Kitsch">기타 기능</a>
# </td>
# </tr>, <tr albumid="4085992" artistid="20158908" multiartist="N" mvid="616618" rowtype="track" trackid="6197837">
# <input name="_isStream" type="hidden" value="6197837"/>
# <input name="_isDown" type="hidden" value="6197837"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="UNFORGIVEN (feat. Nile Rodgers)" type="checkbox" value="6197837"/></td>
# <td>
# <div class="ranking">
# <strong>7</strong>
# <p class="change none"><em>0</em><span>변동없음</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4085992?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="UNFORGIVEN 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40859/4085992.jpg?version=20230525012543.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6197837?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6197837',true);
# " title="UNFORGIVEN (feat. Nile Rodgers)">UNFORGIVEN (feat. Nile Rodgers)</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/20158908?wl_ref=list_tr_10_chart" onclick="
# " title="LE SSERAFIM (르세라핌)">LE SSERAFIM (르세라핌)</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4085992?wl_ref=list_tr_11_chart" onclick="
# " title="UNFORGIVEN">UNFORGIVEN</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6197837',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6197837');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6197837');
# " track_title="UNFORGIVEN (feat. Nile Rodgers)">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6197837','true','true','44.1','true','44.1', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6197837, 616618, 'Y', 'Y', 'Y', 'Y', 6197837, 'N','OVER_15', 'Y');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="LE SSERAFIM (르세라핌)" artist_id="20158908" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6197837','0','4085992','bugs.music.listenRadioFromSeed(\'6197837\',\'track\');','N', 'Y', '_chart');
# " track_title="UNFORGIVEN (feat. Nile Rodgers)">기타 기능</a>
# </td>
# </tr>, <tr albumid="4078016" artistid="20164333" multiartist="N" mvid="610554" rowtype="track" trackid="6170217">
# <input name="_isStream" type="hidden" value="6170217"/>
# <input name="_isDown" type="hidden" value="6170217"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="Hype Boy" type="checkbox" value="6170217"/></td>
# <td>
# <div class="ranking">
# <strong>8</strong>
# <p class="change none"><em>0</em><span>변동없음</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4078016?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="NewJeans 1st EP 'New Jeans' 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40780/4078016.jpg?version=20221014011218.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6170217?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6170217',true);
# " title="Hype Boy">Hype Boy</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/20164333?wl_ref=list_tr_10_chart" onclick="
# " title="NewJeans">NewJeans</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4078016?wl_ref=list_tr_11_chart" onclick="
# " title="NewJeans 1st EP 'New Jeans'">NewJeans 1st EP 'New Jeans'</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6170217',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6170217');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6170217');
# " track_title="Hype Boy">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6170217','true','true','44.1','false','48', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6170217, 610554, 'Y', 'Y', 'Y', 'Y', 6170217, 'N','ALL', 'Y');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="NewJeans" artist_id="20164333" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6170217','0','4078016','bugs.music.listenRadioFromSeed(\'6170217\',\'track\');','N', 'Y', '_chart');
# " track_title="Hype Boy">기타 기능</a>
# </td>
# </tr>, <tr albumid="4082425" artistid="20164333" multiartist="N" mvid="613861" rowtype="track" trackid="6184997">
# <input name="_isStream" type="hidden" value="6184997"/>
# <input name="_isDown" type="hidden" value="6184997"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="Ditto" type="checkbox" value="6184997"/></td>
# <td>
# <div class="ranking">
# <strong>9</strong>
# <p class="change none"><em>0</em><span>변동없음</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4082425?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="NewJeans 'OMG' 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40824/4082425.jpg?version=20230105002539.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6184997?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6184997',true);
# " title="Ditto">Ditto</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/20164333?wl_ref=list_tr_10_chart" onclick="
# " title="NewJeans">NewJeans</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4082425?wl_ref=list_tr_11_chart" onclick="
# " title="NewJeans 'OMG'">NewJeans 'OMG'</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6184997',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6184997');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6184997');
# " track_title="Ditto">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6184997','true','true','44.1','true','44.1', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6184997, 613861, 'Y', 'Y', 'Y', 'Y', 6184997, 'N','ALL', 'Y');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="NewJeans" artist_id="20164333" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6184997','0','4082425','bugs.music.listenRadioFromSeed(\'6184997\',\'track\');','N', 'Y', '_chart');
# " track_title="Ditto">기타 기능</a>
# </td>
# </tr>, <tr albumid="31755650" artistid="80286124" multiartist="N" mvid="0" rowtype="track" trackid="103259794">
# <input name="_isStream" type="hidden" value="103259794"/>
# <input name="_isDown" type="hidden" value="103259794"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="Steal The Show (From “엘리멘탈”)" type="checkbox" value="103259794"/></td>
# <td>
# <div class="ranking">
# <strong>10</strong>
# <p class="change none"><em>0</em><span>변동없음</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/31755650?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="Steal The Show (From “엘리멘탈”) 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/317556/31755650.jpg?version=20230617011201.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/103259794?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('103259794',true);
# " title="Steal The Show (From “엘리멘탈”)">Steal The Show (From “엘리멘탈”)</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/80286124?wl_ref=list_tr_10_chart" onclick="
# " title="Lauv(라우브)">Lauv(라우브)</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/31755650?wl_ref=list_tr_11_chart" onclick="
# " title="Steal The Show (From “엘리멘탈”)">Steal The Show (From “엘리멘탈”)</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('103259794',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('103259794');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'103259794');
# " track_title="Steal The Show (From “엘리멘탈”)">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'103259794','true','true','44.1','false','', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <span class="btn viewMV">영상 재생 불가</span>
# </td>
# <td>
# <a artist_disp_nm="Lauv(라우브)" artist_id="80286124" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'103259794','0','31755650','bugs.music.listenRadioFromSeed(\'103259794\',\'track\');','N', 'Y', '_chart');
# " track_title="Steal The Show (From “엘리멘탈”)">기타 기능</a>
# </td>
# </tr>, <tr albumid="20548488" artistid="80376162" multiartist="N" mvid="615751" rowtype="track" trackid="32784610">
# <input name="_isStream" type="hidden" value="32784610"/>
# <input name="_isDown" type="hidden" value="32784610"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="Cupid" type="checkbox" value="32784610"/></td>
# <td>
# <div class="ranking">
# <strong>11</strong>
# <p class="change up"><span class="arrow"></span> <em>1</em> <span>계단 상승</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/20548488?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="The Beginning: Cupid 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/205484/20548488.jpg?version=20230318003746.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/32784610?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('32784610',true);
# " title="Cupid">Cupid</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/80376162?wl_ref=list_tr_10_chart" onclick="
# " title="FIFTY FIFTY">FIFTY FIFTY</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/20548488?wl_ref=list_tr_11_chart" onclick="
# " title="The Beginning: Cupid">The Beginning: Cupid</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('32784610',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('32784610');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'32784610');
# " track_title="Cupid">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'32784610','true','true','44.1','true','96', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,32784610, 615751, 'Y', 'Y', 'Y', 'Y', 32784610, 'N','ALL', 'N');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="FIFTY FIFTY" artist_id="80376162" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'32784610','0','20548488','bugs.music.listenRadioFromSeed(\'32784610\',\'track\');','N', 'Y', '_chart');
# " track_title="Cupid">기타 기능</a>
# </td>
# </tr>, <tr albumid="4085673" artistid="80169222" multiartist="N" mvid="616389" rowtype="track" trackid="6196923">
# <input name="_isStream" type="hidden" value="6196923"/>
# <input name="_isDown" type="hidden" value="6196923"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="헤어지자 말해요" type="checkbox" value="6196923"/></td>
# <td>
# <div class="ranking">
# <strong>12</strong>
# <p class="change down"><span class="arrow"></span> <em>1</em> <span>계단 하락</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4085673?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="1집 Alone 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40856/4085673.jpg?version=20230421064519.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6196923?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6196923',true);
# " title="헤어지자 말해요">헤어지자 말해요</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/80169222?wl_ref=list_tr_10_chart" onclick="
# " title="박재정">박재정</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4085673?wl_ref=list_tr_11_chart" onclick="
# " title="1집 Alone">1집 Alone</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6196923',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6196923');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6196923');
# " track_title="헤어지자 말해요">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6196923','true','true','44.1','true','48', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6196923, 616389, 'Y', 'Y', 'Y', 'Y', 6196923, 'N','ALL', 'N');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="박재정" artist_id="80169222" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6196923','0','4085673','bugs.music.listenRadioFromSeed(\'6196923\',\'track\');','N', 'Y', '_chart');
# " track_title="헤어지자 말해요">기타 기능</a>
# </td>
# </tr>, <tr albumid="4078016" artistid="20164333" multiartist="N" mvid="610028" rowtype="track" trackid="6170060">
# <input name="_isStream" type="hidden" value="6170060"/>
# <input name="_isDown" type="hidden" value="6170060"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="Attention" type="checkbox" value="6170060"/></td>
# <td>
# <div class="ranking">
# <strong>13</strong>
# <p class="change up"><span class="arrow"></span> <em>2</em> <span>계단 상승</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4078016?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="NewJeans 1st EP 'New Jeans' 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40780/4078016.jpg?version=20221014011218.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6170060?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6170060',true);
# " title="Attention">Attention</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/20164333?wl_ref=list_tr_10_chart" onclick="
# " title="NewJeans">NewJeans</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4078016?wl_ref=list_tr_11_chart" onclick="
# " title="NewJeans 1st EP 'New Jeans'">NewJeans 1st EP 'New Jeans'</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6170060',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6170060');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6170060');
# " track_title="Attention">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6170060','true','true','44.1','false','48', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6170060, 610028, 'Y', 'Y', 'Y', 'Y', 6170060, 'N','OVER_12', 'Y');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="NewJeans" artist_id="20164333" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6170060','0','4078016','bugs.music.listenRadioFromSeed(\'6170060\',\'track\');','N', 'Y', '_chart');
# " track_title="Attention">기타 기능</a>
# </td>
# </tr>, <tr albumid="4085791" artistid="80232283" multiartist="N" mvid="616471" rowtype="track" trackid="6197215">
# <input name="_isStream" type="hidden" value="6197215"/>
# <input name="_isDown" type="hidden" value="6197215"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="손오공" type="checkbox" value="6197215"/></td>
# <td>
# <div class="ranking">
# <strong>14</strong>
# <p class="change down"><span class="arrow"></span> <em>1</em> <span>계단 하락</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4085791?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="SEVENTEEN 10th Mini Album ‘FML' 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40857/4085791.jpg?version=20230509004441.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6197215?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6197215',true);
# " title="손오공">손오공</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/80232283?wl_ref=list_tr_10_chart" onclick="
# " title="세븐틴(SEVENTEEN)">세븐틴(SEVENTEEN)</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4085791?wl_ref=list_tr_11_chart" onclick="
# " title="SEVENTEEN 10th Mini Album ‘FML'">SEVENTEEN 10th Mini Album ‘FML'</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6197215',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6197215');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6197215');
# " track_title="손오공">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6197215','true','true','44.1','true','96', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6197215, 616471, 'Y', 'Y', 'Y', 'Y', 6197215, 'N','ALL', 'Y');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="세븐틴(SEVENTEEN)" artist_id="80232283" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6197215','0','4085791','bugs.music.listenRadioFromSeed(\'6197215\',\'track\');','N', 'Y', '_chart');
# " track_title="손오공">기타 기능</a>
# </td>
# </tr>, <tr albumid="4082425" artistid="20164333" multiartist="N" mvid="614199" rowtype="track" trackid="6186207">
# <input name="_isStream" type="hidden" value="6186207"/>
# <input name="_isDown" type="hidden" value="6186207"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="OMG" type="checkbox" value="6186207"/></td>
# <td>
# <div class="ranking">
# <strong>15</strong>
# <p class="change down"><span class="arrow"></span> <em>1</em> <span>계단 하락</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4082425?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="NewJeans 'OMG' 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40824/4082425.jpg?version=20230105002539.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6186207?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6186207',true);
# " title="OMG">OMG</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/20164333?wl_ref=list_tr_10_chart" onclick="
# " title="NewJeans">NewJeans</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4082425?wl_ref=list_tr_11_chart" onclick="
# " title="NewJeans 'OMG'">NewJeans 'OMG'</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6186207',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6186207');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6186207');
# " track_title="OMG">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6186207','true','true','44.1','true','44.1', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6186207, 614199, 'Y', 'Y', 'Y', 'Y', 6186207, 'N','OVER_12', 'Y');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="NewJeans" artist_id="20164333" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6186207','0','4082425','bugs.music.listenRadioFromSeed(\'6186207\',\'track\');','N', 'Y', '_chart');
# " track_title="OMG">기타 기능</a>
# </td>
# </tr>, <tr albumid="4085066" artistid="80265677" multiartist="N" mvid="616011" rowtype="track" trackid="6195057">
# <input name="_isStream" type="hidden" value="6195057"/>
# <input name="_isDown" type="hidden" value="6195057"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="꽃" type="checkbox" value="6195057"/></td>
# <td>
# <div class="ranking">
# <strong>16</strong>
# <p class="change none"><em>0</em><span>변동없음</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4085066?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="ME 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40850/4085066.jpg?version=20230411020709.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6195057?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6195057',true);
# " title="꽃">꽃</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/80265677?wl_ref=list_tr_10_chart" onclick="
# " title="지수(JISOO)">지수(JISOO)</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4085066?wl_ref=list_tr_11_chart" onclick="
# " title="ME">ME</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6195057',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6195057');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6195057');
# " track_title="꽃">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6195057','true','true','44.1','true','48', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6195057, 616011, 'Y', 'Y', 'Y', 'Y', 6195057, 'N','ALL', 'N');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="지수(JISOO)" artist_id="80265677" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6195057','0','4085066','bugs.music.listenRadioFromSeed(\'6195057\',\'track\');','N', 'Y', '_chart');
# " track_title="꽃">기타 기능</a>
# </td>
# </tr>, <tr albumid="4087619" artistid="80044237" multiartist="N" mvid="0" rowtype="track" trackid="6204237">
# <input name="_isStream" type="hidden" value="6204237"/>
# <input name="_isDown" type="hidden" value="6204237"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="JUICE" type="checkbox" value="6204237"/></td>
# <td>
# <div class="ranking">
# <strong>17</strong>
# <p class="change up"><span class="arrow"></span> <em>3</em> <span>계단 상승</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4087619?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="HARD - The 8th Album 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40876/4087619.jpg?version=20230627012147.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6204237?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6204237',true);
# " title="JUICE">JUICE</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/80044237?wl_ref=list_tr_10_chart" onclick="
# " title="SHINee (샤이니)">SHINee (샤이니)</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4087619?wl_ref=list_tr_11_chart" onclick="
# " title="HARD - The 8th Album">HARD - The 8th Album</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6204237',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6204237');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6204237');
# " track_title="JUICE">내 앨범에 담기</a>
# </td>
# <td>
# ...
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6189186, 614820, 'Y', 'Y', 'Y', 'Y', 6189186, 'N','ALL', 'N');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="STAYC(스테이씨)" artist_id="80347276" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6189186','0','4083531','bugs.music.listenRadioFromSeed(\'6189186\',\'track\');','N', 'Y', '_chart');
# " track_title="Poppy (Korean Ver.)">기타 기능</a>
# </td>
# </tr>, <tr albumid="4087967" artistid="80025838" multiartist="N" mvid="617721" rowtype="track" trackid="6203861">
# <input name="_isStream" type="hidden" value="6203861"/>
# <input name="_isDown" type="hidden" value="6203861"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="사랑하지 않아서 그랬니" type="checkbox" value="6203861"/></td>
# <td>
# <div class="ranking">
# <strong>96</strong>
# <p class="change down"><span class="arrow"></span> <em>2</em> <span>계단 하락</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4087967?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="사랑하지 않아서 그랬니 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40879/4087967.jpg?version=20230623064513.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6203861?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6203861',true);
# " title="사랑하지 않아서 그랬니">사랑하지 않아서 그랬니</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/80025838?wl_ref=list_tr_10_chart" onclick="
# " title="지아(Zia)">지아(Zia)</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4087967?wl_ref=list_tr_11_chart" onclick="
# " title="사랑하지 않아서 그랬니">사랑하지 않아서 그랬니</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6203861',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6203861');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6203861');
# " track_title="사랑하지 않아서 그랬니">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6203861','true','true','44.1','false','', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6203861, 617721, 'Y', 'Y', 'Y', 'Y', 6203861, 'N','ALL', 'Y');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="지아(Zia)" artist_id="80025838" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6203861','0','4087967','bugs.music.listenRadioFromSeed(\'6203861\',\'track\');','N', 'Y', '_chart');
# " track_title="사랑하지 않아서 그랬니">기타 기능</a>
# </td>
# </tr>, <tr albumid="4086865" artistid="80178689" multiartist="N" mvid="617130" rowtype="track" trackid="6200268">
# <input name="_isStream" type="hidden" value="6200268"/>
# <input name="_isDown" type="hidden" value="6200268"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="한강에서 (Feat. BIG Naughty)" type="checkbox" value="6200268"/></td>
# <td>
# <div class="ranking">
# <strong>97</strong>
# <p class="change down"><span class="arrow"></span> <em>36</em> <span>계단 하락</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4086865?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="한강에서 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40868/4086865.jpg?version=20230526064231.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6200268?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6200268',true);
# " title="한강에서 (Feat. BIG Naughty)">한강에서 (Feat. BIG Naughty)</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/80178689?wl_ref=list_tr_10_chart" onclick="
# " title="폴킴(Paul Kim)">폴킴(Paul Kim)</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4086865?wl_ref=list_tr_11_chart" onclick="
# " title="한강에서">한강에서</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6200268',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6200268');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6200268');
# " track_title="한강에서 (Feat. BIG Naughty)">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6200268','true','true','44.1','true','96', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6200268, 617130, 'Y', 'Y', 'Y', 'Y', 6200268, 'N','ALL', 'Y');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="폴킴(Paul Kim)" artist_id="80178689" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6200268','0','4086865','bugs.music.listenRadioFromSeed(\'6200268\',\'track\');','N', 'Y', '_chart');
# " track_title="한강에서 (Feat. BIG Naughty)">기타 기능</a>
# </td>
# </tr>, <tr albumid="4032926" artistid="80072173" multiartist="Y" mvid="588899" rowtype="track" trackid="6083049">
# <input name="_isStream" type="hidden" value="6083049"/>
# <input name="_isDown" type="hidden" value="6083049"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="Leave The Door Open" type="checkbox" value="6083049"/></td>
# <td>
# <div class="ranking">
# <strong>98</strong>
# <p class="change up"><span class="arrow"></span> <em>8</em> <span>계단 상승</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4032926?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="An Evening With Silk Sonic 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40329/4032926.jpg?version=20230510005300.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6083049?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6083049',true);
# " title="Leave The Door Open">Leave The Door Open</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <!-- a tag title -->
# <a class="artistTitle" href="https://music.bugs.co.kr/artist/80072173?wl_ref=list_tr_10_chart" title="Bruno Mars(브루노 마스)">Bruno Mars(브루노 마스)</a>
# <!-- a tag link -->
# <a class="more" href="javascript:void(0);" name="atag_martist_list" onclick="bugs.layermenu.openMultiArtistSearchResultPopLayer(this, 'Bruno Mars||Bruno Mars(브루노 마스)||80072173||OK\\nAnderson.Paak||Anderson.Paak(앤더슨 팩)||80201595||OK\\nSilk Sonic||Silk Sonic||80351786||OK', ''); return false;" title="아티스트 전체보기" wise_log_str="?wl_ref=list_tr_10_chart">
# Bruno Mars(브루노 마스)
# </a> </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4032926?wl_ref=list_tr_11_chart" onclick="
# " title="An Evening With Silk Sonic">An Evening With Silk Sonic</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6083049',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6083049');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6083049');
# " track_title="Leave The Door Open">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6083049','true','true','44.1','true','44.1', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6083049, 588899, 'Y', 'Y', 'Y', 'Y', 6083049, 'N','ALL', 'N');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="Bruno Mars(브루노 마스)" artist_id="80072173" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6083049','0','4032926','bugs.music.listenRadioFromSeed(\'6083049\',\'track\');','N', 'Y', '_chart');
# " track_title="Leave The Door Open">기타 기능</a>
# </td>
# </tr>, <tr albumid="4080055" artistid="20090461" multiartist="Y" mvid="611500" rowtype="track" trackid="6177182">
# <input name="_isStream" type="hidden" value="6177182"/>
# <input name="_isDown" type="hidden" value="6177182"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="딱 10CM만" type="checkbox" value="6177182"/></td>
# <td>
# <div class="ranking">
# <strong>99</strong>
# <p class="change up"><span class="arrow"></span> <em>1</em> <span>계단 상승</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4080055?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="딱 10CM만 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40800/4080055.jpg?version=20221216021840.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6177182?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6177182',true);
# " title="딱 10CM만">딱 10CM만</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <!-- a tag title -->
# <a class="artistTitle" href="https://music.bugs.co.kr/artist/80067149?wl_ref=list_tr_10_chart" title="10CM">10CM</a>
# <!-- a tag link -->
# <a class="more" href="javascript:void(0);" name="atag_martist_list" onclick="bugs.layermenu.openMultiArtistSearchResultPopLayer(this, '10CM||10CM||80067149||OK\\nBIG Naughty||BIG Naughty (서동현)||20090461||OK', ''); return false;" title="아티스트 전체보기" wise_log_str="?wl_ref=list_tr_10_chart">
# 10CM
# </a> </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4080055?wl_ref=list_tr_11_chart" onclick="
# " title="딱 10CM만">딱 10CM만</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6177182',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6177182');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6177182');
# " track_title="딱 10CM만">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6177182','true','true','44.1','false','', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6177182, 611500, 'Y', 'Y', 'Y', 'Y', 6177182, 'N','ALL', 'N');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="BIG Naughty (서동현)" artist_id="20090461" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6177182','0','4080055','bugs.music.listenRadioFromSeed(\'6177182\',\'track\');','N', 'Y', '_chart');
# " track_title="딱 10CM만">기타 기능</a>
# </td>
# </tr>, <tr albumid="4086496" artistid="80067149" multiartist="N" mvid="616895" rowtype="track" trackid="6199216">
# <input name="_isStream" type="hidden" value="6199216"/>
# <input name="_isDown" type="hidden" value="6199216"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="부동의 첫사랑" type="checkbox" value="6199216"/></td>
# <td>
# <div class="ranking">
# <strong>100</strong>
# <p class="change down"><span class="arrow"></span> <em>20</em> <span>계단 하락</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4086496?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="5.4 [부동의 첫사랑] 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40864/4086496.jpg?version=20230515064858.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6199216?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6199216',true);
# " title="부동의 첫사랑">부동의 첫사랑</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/80067149?wl_ref=list_tr_10_chart" onclick="
# " title="10CM">10CM</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4086496?wl_ref=list_tr_11_chart" onclick="
# " title="5.4 [부동의 첫사랑]">5.4 [부동의 첫사랑]</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6199216',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6199216');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6199216');
# " track_title="부동의 첫사랑">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6199216','true','true','44.1','false','', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6199216, 616895, 'Y', 'Y', 'Y', 'Y', 6199216, 'N','ALL', 'Y');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="10CM" artist_id="80067149" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6199216','0','4086496','bugs.music.listenRadioFromSeed(\'6199216\',\'track\');','N', 'Y', '_chart');
# " track_title="부동의 첫사랑">기타 기능</a>
# </td>
# </tr>]

# %%
for song in songs:
    rank = song.select('td > div.ranking > strong')[0].text
    title = song.select(' p.title > a')[0].text
    singer = song.select('p.artist > a')[0].text
    print(rank, title, singer)
# Out:
# 1 퀸카 (Queencard) (여자)아이들
# 2 I AM IVE (아이브)
# 3 HARD SHINee (샤이니)
# 4 이브, 프시케 그리고 푸른 수염의 아내 LE SSERAFIM (르세라핌)
# 5 Spicy aespa
# 6 Kitsch IVE (아이브)
# 7 UNFORGIVEN (feat. Nile Rodgers) LE SSERAFIM (르세라핌)
# 8 Hype Boy NewJeans
# 9 Ditto NewJeans
# 10 Steal The Show (From “엘리멘탈”) Lauv(라우브)
# 11 Cupid FIFTY FIFTY
# 12 헤어지자 말해요 박재정
# 13 Attention NewJeans
# 14 손오공 세븐틴(SEVENTEEN)
# 15 OMG NewJeans
# 16 꽃 지수(JISOO)
# 17 JUICE SHINee (샤이니)
# 18 Thirsty aespa
# 19 사건의 지평선 윤하(Younha/ユンナ)
# 20 Dangerously Charlie Puth(찰리 푸스)
# 21 KNOCK 이채연
# 22 After LIKE IVE (아이브)
# 23 건물 사이에 피어난 장미 (Rose Blossom) H1-KEY (하이키)
# 24 Satellite SHINee (샤이니)
# 25 I Don’t Think That I Like Her Charlie Puth(찰리 푸스)
# 26 Allergy (여자)아이들
# 27 Nxde (여자)아이들
# 28 Teddy Bear STAYC(스테이씨)
# 29 LOVE DIVE IVE (아이브)
# 30 10X SHINee (샤이니)
# 31 ELEVEN IVE (아이브)
# 32 찬란한 하루 멜로망스(MeloMance)
# 33 다정히 내 이름을 부르면 경서예지
# 34 Feel My Rhythm Red Velvet (레드벨벳)
# 35 strawberry moon 아이유(IU)
# 36 도깨비불 (Illusion) aespa
# 37 Pink Venom BLACKPINK
# 38 정이라고 하자 (Feat. 10CM) BIG Naughty (서동현)
# 39 The Feeling SHINee (샤이니)
# 40 ANTIFRAGILE LE SSERAFIM (르세라핌)
# 41 When I Get Old Christopher(크리스토퍼)
# 42 사랑인가 봐 멜로망스(MeloMance)
# 43 Cookie NewJeans
# 44 STAY The Kid LAROI
# 45 FEARLESS LE SSERAFIM (르세라핌)
# 46 나의 바람 (Wind And Wish) 비투비
# 47 That’s Not How This Works (feat. Dan + Shay) Charlie Puth(찰리 푸스)
# 48 파이팅 해야지 (Feat. 이영지) 부석순(SEVENTEEN)
# 49 Off My Face Justin Bieber(저스틴 비버)
# 50 Like It SHINee (샤이니)
# 51 VIBE (feat. Jimin of BTS) 태양
# 52 나의 X에게 경서
# 53 한 페이지가 될 수 있게 DAY6 (데이식스)
# 54 너의 모든 순간 성시경
# 55 심(心) DK(디셈버)
# 56 Heaven(2023) 임재현
# 57 Salty & Sweet aespa
# 58 물론 허각
# 59 Dynamite 방탄소년단
# 60 사실말야내가말야그게그러니까말이야 케이시
# 61 Shut Down BLACKPINK
# 62 오르트구름 윤하(Younha/ユンナ)
# 63 모든 날, 모든 순간 (Every day, Every Moment) 폴킴(Paul Kim)
# 64 사랑은 늘 도망가 임영웅
# 65 FRIEND THE END 볼빨간사춘기
# 66 잠깐 시간 될까 이무진
# 67 SOS 강다니엘(KANG DANIEL)
# 68 Love Me Like This NMIXX
# 69 그라데이션 10CM
# 70 Identity SHINee (샤이니)
# 71 TOMBOY (여자)아이들
# 72 그때 그 순간 그대로 (그그그) WSG워너비 (가야G)
# 73 Candy NCT DREAM
# 74 나에게 그대만이 탑현
# 75 That's Hilarious Charlie Puth(찰리 푸스)
# 76 WHEN I MOVE 카라(Kara)
# 77 해요 (2022) #안녕
# 78 사랑의 바보 제이세라(J-Cera)
# 79 사랑..그게 뭔데 지아(Zia)
# 80 INVU 태연 (TAEYEON)
# 81 CHRISTIAN 지올팍(Zior Park)
# 82 빛이 나는 너에게 던 (DAWN)
# 83 취중고백 김민석 (멜로망스)
# 84 Gravity SHINee (샤이니)
# 85 주저하는 연인들을 위해 잔나비
# 86 불면증 (Insomnia) SHINee (샤이니)
# 87 Cupid (Twin Ver.) FIFTY FIFTY
# 88 Monologue 테이(Tei)
# 89 드라마 아이유(IU)
# 90 Sweet Misery SHINee (샤이니)
# 91 Candy (Feat. Zion.T) 박재범
# 92 특 Stray Kids (스트레이 키즈)
# 93 Broken Melodies NCT DREAM
# 94 NOT SORRY (Feat. pH-1) (Prod. by Slom) 이영지
# 95 Poppy (Korean Ver.) STAYC(스테이씨)
# 96 사랑하지 않아서 그랬니 지아(Zia)
# 97 한강에서 (Feat. BIG Naughty) 폴킴(Paul Kim)
# 98 Leave The Door Open Bruno Mars(브루노 마스)
# 99 딱 10CM만 10CM
# 100 부동의 첫사랑 10CM
